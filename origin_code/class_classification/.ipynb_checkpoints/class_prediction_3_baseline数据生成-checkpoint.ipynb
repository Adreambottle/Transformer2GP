# %%
import sampling
import os
import pandas as pd
import logging
import sklearn
import time
import random
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
import torch
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support,classification_report
import json
import gc
import sys
import re
import generate
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
config_class_features = sampling.read_data("config/config-class-features.json")
config_class_name = sampling.read_data("config/config-class-name.json")
config_classinfo = sampling.read_data("config/config-classinfo.json")
config_numeric_fields = sampling.read_data("config/config-numeric-fields.json")
config_dynamic_units = sampling.read_data("config/config-dynamic-units.json")
pair_params = sampling.read_data("config/pair-params")
class_dict = {'Resistors':1,'Capacitors':2,'others':0}

# %%
def get_data_from_file(path,inputClass,data_num,all_data):
    with open(path,'r', encoding='utf-8') as f:
        standard_data = json.loads(f.read())
    for item in standard_data[:data_num]:
        all_data.append(generate.generate(item, inputClass)['description'])
all_data=[]
get_data_from_file('preprocess/standard_cap.json','Capacitors',10,all_data)
get_data_from_file('preprocess/standard_res.json','Resistors',10,all_data)

# %%
# generate data
cap_data, res_data = [], []
for item in standard_cap[:10]:
    cap_data.append(generate.generate(item, 'Capacitors'))
    
for item in standard_res[:10]:
    res_data.append(generate.generate(item, 'Resistors'))

# %%
cap_data
# Out:
# [{'description': 'CERAMIC/2221_1/8F#0.36kV',
#   'labels': ['others', 'SizeCode', 'Capacitance', 'RatedDCVoltageURdc'],
#   'class': 'Capacitors',
#   'SizeCode': '2221',
#   'Capacitance': '1/8F',
#   'RatedDCVoltageURdc': '0.36kV'},
#  {'description': '7053889124_0.33F-1/8uV',
#   'labels': ['others',
#    'others',
#    'Capacitance',
#    'TemperatureCharacteristicsCode',
#    'SizeCode',
#    'RatedDCVoltageURdc'],
#   'class': 'Capacitors',
#   'Capacitance': '0.33F',
#   'TemperatureCharacteristicsCode': '',
#   'SizeCode': '',
#   'RatedDCVoltageURdc': '1/8uV'},
#  {'description': '1218263915-1210;30pF/0.7V:NP0',
#   'labels': ['others',
#    'SizeCode',
#    'Capacitance',
#    'RatedDCVoltageURdc',
#    'TemperatureCharacteristicsCode'],
#   'class': 'Capacitors',
#   'SizeCode': '1210',
#   'Capacitance': '30pF',
#   'RatedDCVoltageURdc': '0.7V',
#   'TemperatureCharacteristicsCode': 'NP0'},
#  {'description': '0.98F,77V',
#   'labels': ['Capacitance', 'RatedDCVoltageURdc', 'others'],
#   'class': 'Capacitors',
#   'Capacitance': '0.98F',
#   'RatedDCVoltageURdc': '77V'},
#  {'description': '1/4nF:1/5mV',
#   'labels': ['Capacitance', 'RatedDCVoltageURdc', 'others'],
#   'class': 'Capacitors',
#   'Capacitance': '1/4nF',
#   'RatedDCVoltageURdc': '1/5mV'},
#  {'description': '0.52F-24V-2050056824,SMT;2917;TANTALUM (DRY/SOLID)',
#   'labels': ['Capacitance',
#    'RatedDCVoltageURdc',
#    'others',
#    'others',
#    'SizeCode',
#    'TemperatureCharacteristicsCode',
#    'others'],
#   'class': 'Capacitors',
#   'Capacitance': '0.52F',
#   'RatedDCVoltageURdc': '24V',
#   'SizeCode': '2917',
#   'TemperatureCharacteristicsCode': ''},
#  {'description': 'cap:0.18uF;7mV:67%',
#   'labels': ['input class',
#    'others',
#    'Capacitance',
#    'RatedDCVoltageURdc',
#    'PositiveTolerance'],
#   'class': 'Capacitors',
#   'input class': 'cap',
#   'Capacitance': '0.18uF',
#   'RatedDCVoltageURdc': '7mV',
#   'PositiveTolerance': '67%'},
#  {'description': '电容,BULK_0.8nF_0.31,CF_59uV_0603:1007101515',
#   'labels': ['input class',
#    'others',
#    'Capacitance',
#    'PositiveTolerance',
#    'TemperatureCharacteristicsCode',
#    'RatedDCVoltageURdc',
#    'SizeCode',
#    'others'],
#   'class': 'Capacitors',
#   'input class': '电容',
#   'Capacitance': '0.8nF',
#   'PositiveTolerance': '0.31',
#   'TemperatureCharacteristicsCode': 'CF',
#   'RatedDCVoltageURdc': '59uV',
#   'SizeCode': '0603'},
#  {'description': '58uF;1/5mV:62%;CH#0603_SMT',
#   'labels': ['Capacitance',
#    'RatedDCVoltageURdc',
#    'PositiveTolerance',
#    'TemperatureCharacteristicsCode',
#    'SizeCode',
#    'others'],
#   'class': 'Capacitors',
#   'Capacitance': '58uF',
#   'RatedDCVoltageURdc': '1/5mV',
#   'PositiveTolerance': '62%',
#   'TemperatureCharacteristicsCode': 'CH',
#   'SizeCode': '0603'},
#  {'description': '贴片电容:1095122668:SMT-95nF:75%:C0G-TAPE, PAPER:0.96mV;0603',
#   'labels': ['input class',
#    'others',
#    'others',
#    'Capacitance',
#    'PositiveTolerance',
#    'TemperatureCharacteristicsCode',
#    'others',
#    'RatedDCVoltageURdc',
#    'SizeCode'],
#   'class': 'Capacitors',
#   'input class': '贴片电容',
#   'Capacitance': '95nF',
#   'PositiveTolerance': '75%',
#   'TemperatureCharacteristicsCode': 'C0G',
#   'RatedDCVoltageURdc': '0.96mV',
#   'SizeCode': '0603'}]

# %%
#19个resistors的文件*18,12个capacitors的文件*29，总共374个文件,
def convert2str(label_list,item):
    tmp_string = ''

    shuffled_item = list(item.items())
    random.shuffle(shuffled_item)
    
    text, text_sep= "", ""
    deliminter_list = ['#', ',', '/', ';', ':', '-', '_',' ']
    deliminter = random.sample(deliminter_list, 1)[0]
    
    for (key, val) in shuffled_item:
        if key == 'category' or key == 'labels' or key == 'description':
            continue
        elif key == 'class':
            label_list.append(val)
        else:
            if random.uniform(0, 1) > 0.1: # 10% chance to use another deliminter
                tmp_string += str(val) + random.sample(deliminter_list, 1)[0]
            else:
                tmp_string += str(val) + deliminter
                
    output = re.sub("(" + "|".join(deliminter_list) + ")$", "", tmp_string)
    return output

def get_input_from_sampling(input_size: int,train_flag:True):
    """
    input_size: the number of items to sample
    returns the input for simpletransformer
    """
    # 读取所有catogory文件
    path = os.getcwd()
    files= os.listdir('./formatData') #得到文件夹下的所有文件名称
    rs_list = []
    
    # input_size为1表示从每一个category抽取一个样本
    text_list = []
    label_list = []
    problematic = set()
    
    print('进入数据生成循环')
    for file in files: #遍历文件夹
        file_path = os.path.join(path, 'formatData/'+file)
        if os.path.isfile(file_path): #判断是否是文件夹，不是文件夹才打开
            rs = sampling.sampling(file,0.6)
            if 'Resistors' in file:
                for i in range(18*input_size):
                    try:
                        item = [item for item in rs.random_sampling()][0]
                        text_list.append(convert2str(label_list,item)) 
                    except Exception as e:
                        problematic.add(file)
                        continue

            elif 'Capacitors' in file:
                for i in range(29*input_size):
                    try:
                        item = [item for item in rs.random_sampling()][0]
                        text_list.append(convert2str(label_list,item))
                    except Exception as e:
                        problematic.add(file)
                        continue
                        
            else:
                for i in range(input_size):
                    try:
                        item = [item for item in rs.random_sampling()][0]
                        text_list.append(convert2str(label_list,item))
                    except Exception as e:
                        problematic.add(file)
                        continue
    
    #to shuffle input
    res=[]
    for i in range(len(label_list)):
        res.append((text_list[i],label_list[i]))
    random.shuffle(res)
    for i in range(len(label_list)):
        text_list[i]=res[i][0]
        label_list[i]=res[i][1]
        
    print('problematic',problematic)
    print('query数量：',len(text_list))
    print('label数量：',len(label_list))
    
    with open('running_output.txt','a') as f:
        f.write('query数量:'+str(len(text_list))+'\n')
        f.write('label数量:'+str(len(label_list))+'\n')
        f.write('problematic:'+str(problematic)+'\n')
    return text_list,label_list

# a,b=get_input_from_sampling(1,True)
# for i in range(len(b)):
#     print((a[i],b[i]),'\n')
# Out:
# 进入数据生成循环
# problematic set()
# query数量： 1033
# label数量： 1033
# ('3141000.0Ohm,1.25:2512-Dxx342M07B3F83-P:300-Rectangular', 'Resistors')
#
# ('538:SMT,55.0;6/4:4/5e-05_cap;1816_e3#NP0', 'Capacitors')
#
# ('20.0%-500.135µF:45.5uV-Capacitors 20.0%;REFERENCE STANDARD: IEC60384-4 ALUMINUM (WET)_330.0', 'Capacitors')
#
# ('TUBE-MIL-STD-883B,5/6;Amp_0.0-2/6_4/3', 'Amplifier Circuits')
#
# ('Variable Resistors -150,150#15.0%:250100.0O#VERTICAL', 'Resistors')
#
# ('METAL FILM;PTF,0.3kW-Resistors:1235.0Ω:25ppm/°C-TUBULAR PACKAGE', 'Resistors')
#
# ('15.0%:0.022µF WRAPAROUND/1200.0#0201#5000000.0 STANDARD: MIL-PRF-55681, MIL-PRF-123', 'Capacitors')
#
# ('2HP@250VAC 100000.0Cycle(s),283.5;Random/14.0-Power/Signal Relays/545.0Ω/Relays 12.0', 'Relays')
#
# ('6/1-2.54:Display Controllers/8/9MHz-3.5-DISPLAY CONTROLLER, DOT MATRIX LCD DISPLAY', 'Microcontrollers and Processors')
#
# ('THROUGH HOLE MOUNT#3.0uW_2010/4.2/1506.0MΩ 45.0s_Fusible Resistors', 'Resistors')
#
# ('FLATPACK,80166;TIN LEAD_16.0/NOT SPECIFIED_6/1', 'Microcontrollers and Processors')
#
# ('750.0mV-Cap CMR-4/6 9/6°C:e3#125.0°C_0.6e-05µF/MICA_1210', 'Capacitors')
#
# ('-55.0°C,0.1%,0.225mW#155.0°C:Thin Film Resistors:180903.0Ω,Fixed Resistors', 'Resistors')
#
# ('9/4;Tantalum Capacitors/3024#6/7mA,THROUGH HOLE MOUNT,5.75µF/20.0uV_9/3%', 'Capacitors')
#
# ('40.0dB/TRANSMITTER#2500.0Mbps-PANEL MOUNT#1410.0 1/3;e0 1345.5', 'Fiber Optics')
#
# ('13.0_处理器-QFF DMA CONTROLLER-NO_5.0uV;20.0,8.0', 'Microcontrollers and Processors')
#
# ('18.0kV:9/5mm;10/9:AXIAL:10/8mm-55.068mA', 'Thermal Support Devices')
#
# ('512X9#RECTANGULAR;60.0ns:5.0kV#10/2;ASYNCHRONOUS', 'Memory')
#
# ('2_0.764/11.0kΩ-Wire Wound Resistors_8737:2.55%', 'Resistors')
#
# ('5.0pF;75.0/NMP,2.1e-05,NP0,9/9', 'Capacitors')
#
# ('4597.5;NO 8/9;3.3:9/5,0.203mW#11.006K;3.5%', 'Resistors')
#
# ('-10,10/1.6:80.5:2.75-Radial_112.5/0603 Res;23.25', 'Resistors')
#
# ('-150,150/SHAFT-Box,CERMET#735000.0Ω,MIL-PRF-22097,12.5%', 'Resistors')
#
# ('Capacitors_15.0%-1411:4/8µF_TR, 7 Inch-20.0%', 'Capacitors')
#
# ('0705#YES:2_D55342--55.0°C;0.1kW,690.77kΩ_0.1%:125.0°C', 'Resistors')
#
# ('37.5uV;0805-TR, 7 INCH_X7R_NCA#2/9µF:RATED AC VOLTAGE (V): 275', 'Capacitors')
#
# ('Axial:THROUGH HOLE MOUNT:300.0uV/3/2°C 4/7%-5/2e-05µF#-55.0°C:GLASS', 'Capacitors')
#
# ('M080xK2201JBW-;RECTANGULAR PACKAGE#150.0°C:res,-55.0°C-1.165kΩ#100ppm/°C;1.5%#M:0505', 'Resistors')
#
# ('NIOBIUM OXIDE/6/7% 7/9%;45.0µF-Waffle Pack', 'Capacitors')
#
# ('7/5%,57.5µF#3.35mm-105.0°C -55.0°C 2.15kV', 'Capacitors')
#
# ('5.0uV:DTMF SIGNALING CIRCUIT_CMOS 6/9°C/-5.0°C_CEPT PCM-30/E-1:3/5mm/38535Q/M;38534H;883B', 'Telecommunication Circuits')
#
# ('Fixed Resistors#1733_1350001.5Ω/CARBON COMPOSITION_FIXED RESISTOR:Resistors', 'Resistors')
#
# ('Variable Capacitors:4.3e-05-9/7:NO,1816 10/7#50.0', 'Capacitors')
#
# ('24600.0O:-150,150:1.0uW-FLAT e3;4239,Variable Resistors', 'Resistors')
#
# ('YES#9/8°C 80.0°C,2.0,1.375_RF/Noise Generators_50.0kΩ 3/7', 'RF and Microwave')
#
# ('METAL FILM-33.7R;0.811-2#1.0GW:7.925_11.47;4527', 'Resistors')
#
# ('4.6MΩ;400; 500; 850; 1500:电阻 9/6_0.325nW#1406#CBB0207,e3', 'Resistors')
#
# ('-20.0uV:3/7%-135.0mA;-12.0#1/5/106.68mm x 31.75mm x 50.8mm,10.0kHz', 'Oscillators')
#
# ('Resistors-5.0%:Res;NO,0.5nW-4.05mΩ#300.0uV', 'Resistors')
#
# ('GLASS#500.0kV,3.5%_NO#CAPACITANCE TOLERANCE IS 0.25PF/Glass Capacitors/10/6e-05µF', 'Capacitors')
#
# ('AUTO/SELF REFRESH,SYNCHRONOUS DRAM MODULE/2.9V 40.0-5V_1.0', 'Memory')
#
# ('MIL-STD-202_3.0%;176.3kΩ FIXED RESISTOR#e3,10', 'Resistors')
#
# ('50ppm/°C#WIRE WOUND,1.0%#275.0°C 2,RxR81NR_115DRRSL-76.278O/8/10°C', 'Resistors')
#
# ('NIOBIUM OXIDE:1411/3/5µF,10/7°C;7/9°C', 'Capacitors')
#
# ('e4,SURFACE MOUNT-8.06;METAL OXIDE FILM--10,10_25.0:5/3', 'Resistors')
#
# ('1.0GW THROUGH HOLE MOUNT:8520 57.002O#Fixed Resistors:2#2.625%', 'Resistors')
#
# ('18.9,1,YES_50.0ohm#8/8', 'RF and Microwave')
#
# ('7/5µF#CYLINDRICAL PACKAGE-TBC-6000.0,TANTALUM (DRY/SOLID) 4.1_POLARIZED#8/10', 'Capacitors')
#
# ('2.1e-05_CERAMIC:105.0-GKU1xx1_x,112.5_4/1;2/5', 'Capacitors')
#
# ('YES,CERAMIC;MA AEC-Q200,0805_20.0%,5.5,0.075µF', 'Capacitors')
#
# ('3.0%/2.35µF-MIL-PRF-23269_Axial/19.05mm CYR15:500.0uV,GLASS', 'Capacitors')
#
# ('2-55.0mV-9/1% Yes-TR, EMBOSSED PLASTIC, 7 INCH-BP,0.034µF', 'Capacitors')
#
# ('3/10,10.0;CABLE#8/10dB:NICKEL:RF N CONNECTOR#GOLD', 'Connectors')
#
# ('NO/WIRE_MICA_1210:2.501e-07µF', 'Capacitors')
#
# ('C0G,ISOLATED C NETWORK:CERAMIC;Cap#2.44µF-7.5%/ARRAY/NETWORK CAPACITOR-CHIP', 'Capacitors')
#
# ('4/7°C;CARBON COMPOSITION,1.512K;3.0_0.562GW;电阻', 'Resistors')
#
# ('WITH EMITTER BALLASTING RESISTORS#e0:RADIAL_4.0A,7.25#ULTRA HIGH FREQUENCY BAND_1630.0MHz#YES', 'Transistors')
#
# ('TIN LEAD;3.0%,2/8°C_GLASS:400.0uV/8/4°C/Glass Capacitors;4/3mm:3/1µF', 'Capacitors')
#
# ('CMOS/5/6°C/1600.0V/us -15.0mV 77.5°C:100.0MHz', 'Amplifier Circuits')
#
# ('AR05 0.062kW_Chip:0805#10.0MΩ-Resistors', 'Resistors')
#
# ('NO-5.0%:6/2e-05µF/9/6_MICA 25+/-25ppm/Celppm/°C', 'Capacitors')
#
# ('Special Switches/GOLD 42.0V/SPST_3A@115VAC;1000000.0Cycle(s):Switch:28.7mm', 'Switches')
#
# ('METAL STRIP 0.5GW,ANTI-SULFUR-0.012mΩ,2 1.0%_BULK', 'Resistors')
#
# ('0.11/-40.0°C;6/4°C,1040.5,0.1,8.0mA', 'Transformers')
#
# ('3/6Cycle(s)_4622mW/MOMENTARY#8/2#DC', 'Relays')
#
# ('2/10%-2.54/38160.0MΩ;e3:2520#GULL WING/METAL GLAZE/THICK FILM/3.43-SMT', 'Resistors')
#
# ('3/8%:10/7ppm/°C 2244;31.5GΩ/649.0:70.0°C-Tin/Silver/Copper - with Nickel barrier METAL GLAZE/THICK FILM', 'Resistors')
#
# ('1505;THIN FILM:624500.0Ohm 70.0°C_Tin (Sn),YES', 'Resistors')
#
# ('Axial_9/7mm-8739#3.0%,10/3 5.574MΩ', 'Resistors')
#
# ('775.2GΩ-5.0:0603#31.55;0.5pW RLR32Cx110FRB1#4#400.0uV', 'Resistors')
#
# ('e0-1.99µF:POLARIZED#115.0°C:8/9 TANTALUM,12.5%;10/10°C', 'Capacitors')
#
# ('850.0 115007.5µF;1/6%:1/2mA#5000000.0#1308/TANTALUM (DRY/SOLID)', 'Capacitors')
#
# ('5.9,BC#YES,10.75_7/10%;7/2µF', 'Capacitors')
#
# ('70.0°C-20100.21Ohm:2/3/METAL ALLOY 4 Terminals#6/4,2.8uW', 'Resistors')
#
# ('NO 0:2.782mm_处理器_25600.0:0.0,16.0,OTHER YES', 'Microcontrollers and Processors')
#
# ('Connectors#LOCKING:FEMALE,1.52mm/28.0 CABLE,100000000.0-PALLADIUM', 'Connectors')
#
# ('85.0°C:515.0mV_电容 POLYPROPYLENE;-47.5°C 7.84µF -250ppm/Cel', 'Capacitors')
#
# ('C0G:275.0/4/4µF,15.0% 2', 'Capacitors')
#
# ('Fusible Resistors;214.5ohm-Cylindrical;TR;530.0ns,1206/0.188pW', 'Resistors')
#
# ('PbSe_1500-1000000/Infrared Sensors#Transducers,1/2V/W-5.0mm2#-20.0', 'Sensors/Transducers')
#
# ('LG-MAX;SEATED HGT-NOM;WD-MAX:+-15/1325.0MHz 9/5 7.0 -1.5_YES#-15.0V', 'Signal Circuits')
#
# ('340.366K-Rectangular-0.625pW/70.0°C/125.0mV;METAL GLAZE/THICK FILM#0.42-100 2.605', 'Resistors')
#
# ('275.0mV_CERAMIC CL/1.024µF,1/1%,1.525mm,WRAPAROUND', 'Capacitors')
#
# ('20.0%-9000.0#5/10°C#SPECIAL CAPACITOR_POLARIZED/-55.0°C MIL-PRF-55365;5/6µF', 'Capacitors')
#
# ('SDIP-SDAx2x0M:-2-17.062_NOT SPECIFIED', 'Consumer Circuits')
#
# ('NOT SPECIFIED#e0:YES-6/4dB/7/6', 'RF and Microwave')
#
# ('Resistors 1/LINEAR#e3#15.0%_CIRCULAR PACKAGE/0.56nW#105000.0MΩ', 'Resistors')
#
# ('THROUGH HOLE MOUNT;1.75#PLASTIC-50 OHM_SAW Filters#e0-10/3#5.0', 'Filters')
#
# ('1#4.5:TRANSIENT; UNDER VOLTAGE;18.0-0.3#2/6_4.0', 'Drivers And Interfaces')
#
# ('20.0%;5/3 20.0%-2412-6.65mm_10/2µF', 'Capacitors')
#
# ('12.5%-2917;Capacitors;Tantalum Capacitors:7/6µF-M39003/01', 'Capacitors')
#
# ('0.074µF:THROUGH HOLE MOUNT/PAPER;xZR#24BKF474M,600.0uV', 'Capacitors')
#
# ('3/3.3_57.5ns;16K,496K:SPI NOR TYPE;FLASH+PSRAM_64MX16 3-STATE', 'Memory')
#
# ('18.85µF 5250.0#e4 7/6mm#7/4%_TANTALUM (DRY/SOLID)_9/2°C,125.0°C;Tantalum Capacitors', 'Capacitors')
#
# ('3.058/SOLDER#5/1 1000.0,8', 'Connectors')
#
# ('NO Tape & Reel Available NPQ,50.0#4.3e-05,WIRE', 'Capacitors')
#
# ('0.45-6950.0µF;95.0°C:2626,307.5mΩ-TANTALUM CAPACITOR/0.018mA_325.0uV;-40.0°C', 'Capacitors')
#
# ('YES THIN FILM/Film/Foil Resistors:125.0°C,1350000.0Ω,0.55%;0.125MW', 'Resistors')
#
# ('1/NOT SPECIFIED#Interfaces_1.5,1752.25ns DOT MATRIX e0', 'Drivers And Interfaces')
#
# ('285.0K_9/6%#CARBON COMPOSITION_2667#Fixed Resistors TR,0.65', 'Resistors')
#
# ('BULK:2309#2.0%-Carbon Film Resistors-0.5W:1.81Ω_-55.0,AEC-Q200', 'Resistors')
#
# ('6.6,5/5/0402#16.35-0.18_325.0mV/0.02-0.036 OHMS AT 20 DEG CEL; RATED CURRENT: 2.5A', 'Resistors')
#
# ('LIQUID CRYSTAL POLYMER (LCP),20-BOARD-0.184-NO', 'Connectors')
#
# ('350.0#965.0O:4.625GW:2.7;1210;Fusible Resistors/200ppm/°C', 'Resistors')
#
# ('7.505µF#SMT_130.0uV;15.0%#E:POLARIZED 1210;RECTANGULAR PACKAGE', 'Capacitors')
#
# ('30.0,1817/e3-NO_Yes/NPQ,4.25e-06', 'Capacitors')
#
# ('Special Capacitors_10000.0_POLARIZED#2 285.0µF', 'Capacitors')
#
# ('70.0°C_100-RC0x7xAC1xK-0GKFB,1005-375.8kΩ', 'Resistors')
#
# ('2.5mW,8610.0Ohm#100ppm/°C Resistors_NO/2', 'Resistors')
#
# ('6/8°C_275.0 5/3%/TR, EMBOSSED PLASTIC, 7 INCH/125.0°C 3/7µF cap#BR', 'Capacitors')
#
# ('0.113W/ANTI-SULFUR, FLAME PROOF, LASER TRIMMABLE,14600.0R:MIL-PRF-55342 FIXED RESISTOR-25ppm/°C/140.0°C/THIN FILM', 'Resistors')
#
# ('METAL STRIP_TIN LEAD/-150,150ppm/°C-SURFACE MOUNT#0805-贴片电阻/2:5/4_0.024MΩ', 'Resistors')
#
# ('20.5MHz/Ex1_400SJTxDC-19.659M#7.5mm x 5.0mm x 1.6mm_Not Qualified_7/9%:5 TTL, 15 pF#50#60.0', 'Oscillators')
#
# ('5.0_0.5:VERTICAL_1812:55.0 4.3e-0;NPQ', 'Capacitors')
#
# ('405.63MHz/Gold (Au) - with Nickel (Ni) barrier Resonator,3/4%-SURFACE MOUNT', 'Crystals/Resonators')
#
# ('THROUGH HOLE MOUNT 1333 530.0K CARBON COMPOSITION/0.25kW/0.65-Carbon Composition Resistors', 'Resistors')
#
# ('50/54.499;77.5°C_262.5% 3.3kV/1/4°C-1.0', 'Oscillators')
#
# ('252.5:3.4mm x 1.8mm x 1.45mm,-10,10_METAL OXIDE FILM/23502.55/Non-linear Resistors/3715.0--47.5', 'Resistors')
#
# ('FLAT:0.058mA#943.0mΩ:3/1%,5.75µF', 'Capacitors')
#
# ('3.5/150.0mA/IN-LINE:NOT SPECIFIED_235.5kV', 'Trigger Devices')
#
# ('PLASTIC:100.0MHz_100.0MHz-1.75nA-Tape, Paper', 'Filters')
#
# ('0.17/65.0#1.25,NICKEL_1,5.207', 'Connectors')
#
# ('Connectors-7/6,BOARD;10/5#AU_1.4/2.54/RECTANGULAR', 'Connectors')
#
# ('11.8_105.0°C;CERAMIC, METAL-SEALED COFIRED:1.15uV,-20.0°C_2.95arcmin,-10.625kV', 'Converters')
#
# ('3/6:2.045mm_0.3%:39.5K-3050;DIP-6/6-2/4mm', 'Resistors')
#
# ('0.005A_ROTARY POSITION ENCODER:THROUGH HOLE MOUNT#e4/NO/1.0', 'Optoelectronics')
#
# ('38.1:0.625W:电阻/1.0%-1.503mΩ 2/3,HCHP HYBRID', 'Resistors')
#
# ('3985.0Ohm:5/2mm:0.081nW,1.8mm:2-Fixed Resistors;-25,25ppm/°C:0.1%', 'Resistors')
#
# ('6.15;2.55µF#0805-MICA CAPACITOR 400.0mV:MICA TIN', 'Capacitors')
#
# ('B/FR9xAC1A-JQRS.GCDM 15.0:Other Transistors/2300.0MHz-13.5-42.5/SINGLE#YES', 'Transistors')
#
# ('Terminals,8AWG/WIRE TERMINAL,Terminal DTHD:Terminal Blocks-MALE', 'Terminal Blocks')
#
# ('5.0%,VJ COMMERCIAL:1210#5/2µF-5.0,TR, 7 INCH', 'Capacitors')
#
# ('5510000.0GΩ-1.27mm/RECTANGULAR PACKAGE#-100,100ppm/°C;e0:Waffle Pack:0.113pW/3.0%', 'Resistors')
#
# ('10/6;AMBER 2.0mV/9/2#T-1 3/4#4/8deg#TAPE AND REEL 13"-Visible LEDs', 'Optoelectronics')
#
# ('PAPER/2/9°C,300.0kV_6/4µF-8/5°C-CZx23#BKC474M', 'Capacitors')
#
# ('TUBULAR PACKAGE CARBON COMPOSITION;RC-1733,7.5%_Resistors,NO 57.35kΩ', 'Resistors')
#
# ('3.43 6/10%#25ppm/°C-375324.5Ω;8/5-4300T', 'Resistors')
#
# ('AEC-Q200:Metal Strip/Wire Resistors;0805-0.012GΩ;METAL STRIP', 'Resistors')
#
# ('-55.0°C;3.75e-05µF;Glass Capacitors,Axial,4/2%/10/9°C GLASS', 'Capacitors')
#
# ('FLAME PROOF:e3#10163.05GΩ_0.75%#50ppm/°C NO_MIL-PRF-55182#0603', 'Resistors')
#
# ('750.0mV#4.5%/TAPE#Mica Capacitors#17.9#4.75e-05µF MICA', 'Capacitors')
#
# ('15.625/1/10MHz,128.0#10000Ω#4_72.5°C-6/5°C_e4#1 PPM/YEAR 15 pF', 'Oscillators')
#
# ('GLASS:2/7µF:MIL-PRF-23269/02_2_3.0%', 'Capacitors')
#
# ('-20.0°C-PLENUM_2.5,70.0°C#450.0_0.21', 'Connector Support')
#
# ('贴片电容,2.8e-05µF/Capacitors-Axial-400.0mV#1.5%', 'Capacitors')
#
# ('Deflection ICs-13.5 9 DIP,Consumer Circuits', 'Consumer Circuits')
#
# ('0.375GW;6.3/2,50005.0Ohm/5.0%:Carbon Composition Resistors', 'Resistors')
#
# ('Cap_3/1mm:160.0µF,YES,5.15uV,Capacitors:POLARIZED', 'Capacitors')
#
# ('112.815uA;NO;4.405mm-VERY FAST#125.0:BLISTER', 'Circuit Protection')
#
# ('1.5;-20.0°C,77.5°C,5/1#20.25,SMALL OUTLINE, SHRINK PITCH', 'Consumer Circuits')
#
# ('Resistors,CERMET-TR, EMBOSSED, 13 INCH;20.0%_507500.0Ω_1', 'Resistors')
#
# ('127.0uV-231.5VA:Transformers,Constant Voltage Transformers', 'Transformers')
#
# ('0505,SMT,WRAPAROUND;10237.5MΩ#RUTHENIUM OXIDE,70.0,1.5%-2', 'Resistors')
#
# ('100.0/xLY;Ox-0612x:30.0;15.0mV', 'Oscillators')
#
# ('-55.0_37.85mΩ 5044 Resistors:0.75%;2;METAL ALLOY THROUGH HOLE MOUNT/10/9', 'Resistors')
#
# ('1125.5MHz,D12.7XL96.52 (mm)/D0.5XL3.8 (inch):L250 80.0°C 780.0MHz/2.0,1.5--20.0°C#N FEMALE/MALE', 'Filters')
#
# ('11.0kΩ-0603;Resistors,17.725mm#2-350ppm/°C#5/6mm;0.85MW', 'Resistors')
#
# ('0.838mm -55.0°C;SURFACE MOUNT;1.397mm;0505;METAL GLAZE/THICK FILM 1.1pW 70.0;4175.0Ω#150.0°C', 'Resistors')
#
# ('No_NON-POLARIZED/Film Capacitors,0.004µF_3.5%;2824-6.75%', 'Capacitors')
#
# ('12.0-3/10 8085:3/5°C:5.0mV_Parallel IO Port:-20.0°C_GENERAL PURPOSE ZPLD', 'Microcontrollers and Processors')
#
# ('RECTANGULAR PACKAGE#-100,100 -60.0°C/LINEAR-CERMET,110.0mΩ#4.435 Resistors', 'Resistors')
#
# ('ALUMINUM ELECTROLYTIC CAPACITOR/8/4%#5023.5µF_POLARIZED e3', 'Capacitors')
#
# ('1/5µF,TR, 7 INCH_3500.0;TUBULAR PACKAGE,POLARIZED', 'Capacitors')
#
# ('3.985mΩ:AR05;FIXED RESISTOR/0.1%/ARx3BTC1#xRx:0.081pW', 'Resistors')
#
# ('70.0°C QUAD_-27.5°C/CMOS-Telecom Encryption Circuits#4.0kV', 'Telecommunication Circuits')
#
# ('NO/16K,8K,32K,64K#5.25:4.0uV;5V', 'Memory')
#
# ('PTC THERMISTOR:METAL OXIDE FILM#1.125 THROUGH HOLE MOUNT-1265.0 RESISTANCE RANGE(MIN-MAX): 0.020-0.050', 'Resistors')
#
# ('IDE/NO#5.0uV;6/10;17.425 Microcontrollers and Processors 3.525;1/1', 'Microcontrollers and Processors')
#
# ('SIMPLEX/0.354-CABLE#0.285dB_MALE', 'Connectors')
#
# ('SPDT#1/3:LP9 4/9/SOLDER/004x.9x37.2.2.x-.0x5', 'Switches')
#
# ('x32923-A247-4-M000:2/10µF#NON-POLARIZED_电容/4924_1200ppm/Cel', 'Capacitors')
#
# ('Capacitors#TANTALUM (DRY/SOLID),167.35µF,WRAPAROUND,1x3D126X9020X/T 725.0-7.58;25.0V', 'Capacitors')
#
# ('YES RECTANGULAR 5.0uV#R-PDIP-T24 5V;2/7MHz', 'Microcontrollers and Processors')
#
# ('NIOBIUM OXIDE/MIL-PRF-55365 -55.0°C_125.0°C 2.5V-109.0µF:FILM CAPACITOR', 'Capacitors')
#
# ('159PUL-SI/39.15#8/1mA-76.65µF#ALUMINUM (WET)#20.0%_18.25;37.5uV', 'Capacitors')
#
# ('CA,5.0mW TR/2;WIRE WOUND_12300.0O', 'Resistors')
#
# ('RC1/:2x1xJTR,28215.0GΩ_10.0%-FIXED RESISTOR-CARBON COMPOSITION', 'Resistors')
#
# ('20.0%#POLARIZED#-55.0°C#22.5uV-TR, EMBOSSED PLASTIC, 13 INCH,e0;1/8µF_Tantalum Capacitors 8/5°C', 'Capacitors')
#
# ('2.35_THIN FILM;0.055%,Fixed Resistors;Resistors_1005;3.65mΩ,3/2°C', 'Resistors')
#
# ('Terminal Blocks#Terminal Blocks', 'Terminal Blocks')
#
# ('8/4µF_500.0uV;GLASS WIRE STANDARD: MIL-C-11015/25', 'Capacitors')
#
# ('4.119µF 7.5%/10.16;VJ1x06Y8x;1JXJAP68:0603;-55.0°C;CERAMIC,SMT-8/1°C', 'Capacitors')
#
# ('INPUT TYPE CAN ALSO ACCEPTS YCRCB/SOP-PAL-RGB; R-Y; B-Y; Y,Not Qualified', 'Consumer Circuits')
#
# ('SOP14,.25_1.6 1/8/Amplifier Circuits#0.2µA Comparators_NO:10.0V', 'Amplifier Circuits')
#
# ('0.0µF-MA#7.5%;METALLIZED FILM_CERAMIC NCA', 'Capacitors')
#
# ('18004.03O/METAL GLAZE/THICK FILM;25ppm/°C_Tin/Copper (Sn/Cu)_res-70.0°C', 'Resistors')
#
# ('98.5µF,5750.0:NBSEx77M00xCR;SC072x:1411-5/8mm', 'Capacitors')
#
# ('IN-LINE/4.5/20,TTL/H/L_10/9ns', 'Logic')
#
# ('2309:2115.0ohm 2.0%,28.0/-250:3.1#LUG', 'Resistors')
#
# ('5/3/2/10 12 100k Rad(Si)/5#HYBRID,8', 'Signal Circuits')
#
# ('6/9µF_5.09_NIOBIUM/-55.0°C Special Capacitors:3/6°C 6.3V:15000.0', 'Capacitors')
#
# ('CMOS/1/3.5:6.7mV#Paging Circuits,QUAD', 'Telecommunication Circuits')
#
# ('2:4.4mV-5.0:cap 1206_97.5°C,14000.0/-55.0°C#Capacitors;415.0µF', 'Capacitors')
#
# ('2.275mm-CERAMIC;0.002µF RATED AC VOLTAGE (V): 275/0805 30.0mV#Capacitors/2.0', 'Capacitors')
#
# ('BREAK-BEFORE-MAKE/0.307/CIRCULAR_GOLD OVER NICKEL 1/4mm-0.1kA-0.15', 'Switches')
#
# ('0.5mW;WSLP080xR0/1x4FEK_3/4% Matte Tin (Sn);0805;-65.0°C-170.0°C-0.015Ω;ANTI-SULFUR', 'Resistors')
#
# ('0.001µF#0805,GOLD CERAMIC 1.52mm;C0G_SMT', 'Capacitors')
#
# ('Fixed Resistors/0.013Ohm-5/9mm#METAL STRIP:75ppm/°C:2.03mm', 'Resistors')
#
# ('260.0ohm--150,150-CONDUCTIVE PLASTIC-6/7_Variable Resistors,295.0', 'Resistors')
#
# ('METAL OXIDE FILM 5.0,电阻;2-38.1mm;0.75uW#FLAME PROOF#55150.0Ω', 'Resistors')
#
# ('0.1mW 755500.0GΩ#E/H(T-LEVEL),THIN FILM;TR,1206-D55342', 'Resistors')
#
# ('10.0-Shorter Tereminal Available Upon Request:3333#197.5mΩ;12.65µF#Box:330.0_ALUMINUM (WET)', 'Capacitors')
#
# ('8350.0µF-9.4 FB 100.0;10.0-10.0pA', 'Filters')
#
# ('-25,25ppm/°C;SMT-3985.0GΩ:TANTALUM NITRIDE/NICKEL CHROME_Tantalum Nitride/Nickel Chrome Resistors;0.1pW#AR03', 'Resistors')
#
# ('1000VRMS,MIL-STD 28.0;ON-ON:2A@250VAC,9/2/0.01:SPDT', 'Switches')
#
# ('LATCHED,28.0uV/75000.0;5/8/DC:Relay', 'Relays')
#
# ('25.0:2.05e-06;7/5-75.0/-47.5#4.25pF', 'Capacitors')
#
# ('4527;Axial-6.0mW;WIRE WOUND 10/6:155.0MΩ-Fixed Resistors', 'Resistors')
#
# ('COAX#0.3dB-.278 1.225#LOCKING:POLYSTYROL', 'Connectors')
#
# ('1206_125.0°C:1/1°C/D55342#0.1uW#SURFACE MOUNT 109770.0GΩ;MIL-PRF-55342/0.1%', 'Resistors')
#
# ('0.0MHz:0.175;124.0_Gold (Au) MOMENTARY/4000.0MHz,8/2mm;R573/17.5ms,Relays', 'Relays')
#
# ('MICA_500.0uV-3.5e-06µF,NO/5.0%,TR/25+/-25ppm/Celppm/°C', 'Capacitors')
#
# ('SURFACE MOUNT,MICA/7.05e-06µF#4.2:291/7.5%;400.0kV', 'Capacitors')
#
# ('贴片电阻_1406/SMT/3.83mΩ;Tin/Lead (Sn/Pb) CARBON FILM 8/2°C#-250', 'Resistors')
#
# ('8.6µF-AMMO PACK 10.0% 2/6°C-22.5mV;SURFACE MOUNT_-55.0°C', 'Capacitors')
#
# ('30.0uV#61.1µF 0.12 7.3mm CWR06 POLARIZED-TANTALUM (DRY/SOLID)', 'Capacitors')
#
# ('340.6mΩ-200ppm/°C#Matte Tin (Sn) 1.75nW:60.0us 70.0-4/1', 'Resistors')
#
# ('7/7:SMALL OUTLINE#0.465Ohm,e0;3.2#117.5_17.0', 'Transistors')
#
# ('400000.0Cycle(s);1X1-24.0mV_SPST_VERTICAL,1241;0.5A@12VDC', 'Switches')
#
# ('0.255pF SILICON:CERAMIC, METAL-SEALED COFIRED-O-CEMW-N2;ROUND#0.42', 'Diodes')
#
# ('175.0uV WIRE,165.41µF ALUMINUM (WET)/BULK', 'Capacitors')
#
# ('Connectors#1.4 2/2-SINGLE/126um#50.0-e3 135.0', 'Connectors')
#
# ('e4-YES:33.5dB 0.1;0.75 LCC20,.16SQ,20;COMPONENT#3/3', 'RF and Microwave')
#
# ('UL, CSA 2.5-STAINLESS STEEL-10/2#0.171;5000000000.0-GOLD (50)-PANEL', 'Connectors')
#
# ('100.15-57.745 SIGNAL_0.095 9/5/3/4mm', 'Transformers')
#
# ('395.5K:100ppm/°C/THIN FILM:SURFACE MOUNT:Resistors;112.5uV/Fixed Resistors:2;1010', 'Resistors')
#
# ('TR, 7 INCH/4/2% CERAMIC,NCA:6/1µF', 'Capacitors')
#
# ('6/4,0.0,240;-20.0°C/Microcontrollers 5.0mV/8/5°C-N', 'Microcontrollers and Processors')
#
# ('2.835mΩ,0.1W/150.0°C MIL-PRF-55182/9#0805-贴片电阻 1ppm/°C;RECTANGULAR PACKAGE_YES', 'Resistors')
#
# ('PANEL:3_-32.5-1A, 250V#Connectors,4/10-POLYETHYLENE:FEMALE', 'Connectors')
#
# ('0.175%_95.0V/25ppm/°C:Resistors,THIN FILM 239880.0Ohm;2.032 0.254', 'Resistors')
#
# ('QUAD/+3.4V;Signal Circuits/3/ALSO REQUIRES -4.5V TO -16.5V, +4.5V TO +5.5V AND +13.5V TO +16.5V SUPPLIES:10.0kV', 'Signal Circuits')
#
# ('15% 75.0mV_2.357µF;POLARIZED_Fixed Capacitors', 'Capacitors')
#
# ('R-7x5I1820AA0J;电容_NON-POLARIZED-12.5%;2.11µF#2', 'Capacitors')
#
# ('res 100ppm/°C#1.397mm:2700.0GΩ/M2010(FTOL)_9/1%#Tin/Lead (Sn/Pb) - with Nickel (Ni) barrier 6/7_RUTHENIUM OXIDE;8/6mm', 'Resistors')
#
# ('26.0 SPDT#12.5#6A@250VAC-72.5uV', 'Switches')
#
# ('SURFACE MOUNT/CERAMIC CAPACITOR,MIL-PRF-55681/7/RECTANGULAR PACKAGE-C0G 4/8% 9/4µF,CERAMIC', 'Capacitors')
#
# ('Resistors:METAL FILM:255.084K 30.5us,1/8', 'Resistors')
#
# ('PLASTIC/EPOXY;SILICON;135.4mA/UNIDIRECTIONAL;0.4mW', 'Diodes')
#
# ('10/1%_SURFACE MOUNT#Capacitors,0.016µF-0805 CERAMIC,15%ppm/°C', 'Capacitors')
#
# ('CERAMIC CAPACITOR,Cap;Matte Tin (Sn) - with Nickel (Ni) barrier_CERAMIC/0.903µF 2.1mm 550.0kV', 'Capacitors')
#
# ('2/4:FIBER OPTIC BICONIC CONNECTOR/NO_126um', 'Connectors')
#
# ('0.08:6.8mm_12.5%:4.5µF 7250.0', 'Capacitors')
#
# ('3533#5/10µF,8.515 275.0mV,THROUGH HOLE MOUNT', 'Capacitors')
#
# ('7.75kV/6/10_2/1 63.5mA/2.5_e0:SERIAL', 'Converters')
#
# ('ROUND/Photo Diodes_TR, 7 INCH_NO-1.0_Optoelectronics#940nm', 'Optoelectronics')
#
# ('POLYESTER-4,15.0/26.0-2.444;10u', 'Connectors')
#
# ('THROUGH HOLE MOUNT#420.95Ω;0805:3.11mm/50ppm/°C/e0-0.325,THIN FILM', 'Resistors')
#
# ('170.0°C#METAL STRIP#9/4%,电阻:WRAPAROUND,YES/75ppm/°C-0.013Ω-7/6°C', 'Resistors')
#
# ('2.0-50.0ohm#8/4,YES-1:3.3;9/8dB', 'RF and Microwave')
#
# ('55.235O,1.95 Resistors-CARBON FILM/1406-Carbon Film Resistors res', 'Resistors')
#
# ('15.0%/126.5µF -55.0°C_MIL-PRF-55365_3.55mm/1411;85.0°C', 'Capacitors')
#
# ('4.5µF TR#0/+70ppm/Celppm/°C-WIRE:4/6%/电容#200.0mV', 'Capacitors')
#
# ('e0-THIN FILM:NON-INDUCTIIVE, LASER TRIMMABLE/0402#10ppm/°C,Tin/Lead (Sn/Pb) - with Nickel (Ni) barrier 3.615K/137.5°C,2/6°C;贴片电阻', 'Resistors')
#
# ('+140+/-25ppm/Celppm/°C_NO_9/3µF;WIRE:GLASS:500.0V', 'Capacitors')
#
# ('57.0mΩ#15.0% Shorter Tereminal Available Upon Request;Cap:3.74µF,IEC60384-4', 'Capacitors')
#
# ('20.0%#636605.0mΩ/ALUMINUM ELECTROLYTIC CAPACITOR_2/3°C/9/9°C;B43541:POLARIZED/AEC-Q200#6/8µF', 'Capacitors')
#
# ('MIL-C-81,NP0_5/5/4.3e-0#75.0 Cap', 'Capacitors')
#
# ('28001.65µF,42.5kV 12.15-TR#TANTALUM (DRY/SOLID)', 'Capacitors')
#
# ('0.225mA,40.0mA/4/5µs/e0#NO THROUGH HOLE MOUNT', 'Sensors/Transducers')
#
# ('7/4°C#38.1mm#3/10:167.5°C_1.75nW 281011.0Ohm/50ppm/°C', 'Resistors')
#
# ('SURFACE MOUNT_1206/C0G/5/3e-05µF 6.0%;30ppm/Celppm/°C_MIL-PRF-55681/8-MIL-PRF-55681', 'Capacitors')
#
# ('RF SC Connectors-FEMALE_POLARIZED-0.15_-65.0-1#POLYTETRAFLUORO ETHYLENE', 'Connectors')
#
# ('6/4µF#400.0uV,2:10/2%_5.11#-55.0°C 6114 125.0°C', 'Capacitors')
#
# ('300ppm/°C/M55342/08-THIN FILM/0402:10/2mm:WRAPAROUND/302.034mΩ', 'Resistors')
#
# ('5/1#Tin/Lead (Sn/Pb):-55.0#Trigger Devices#137.5', 'Trigger Devices')
#
# ('WAFFLE PACK/7.5%;4.113e-05µF/VJ_0805', 'Capacitors')
#
# ('DIGITAL OUTPUT,Sensors_7/6°C SOLDER:12.0;12.75#3408.0/4/8°C', 'Sensors/Transducers')
#
# ('cap,3/8µF;MIL-C-11693/7:400.0mV/PAPER:2', 'Capacitors')
#
# ('Power Circuits-MICROELECTRONIC ASSEMBLY/1.5;24V:216.0uV-VOLTAGE-MODE', 'Power Circuits')
#
# ('Radial:POLYPROPYLENE-NON-POLARIZED#2:3916/11.5mm_5/2µF', 'Capacitors')
#
# ('8/3µF;7.5%/BX:RECTANGULAR PACKAGE_2', 'Capacitors')
#
# ('SILICON;NOT SPECIFIED,0.25MW,PIN Diodes,Not Qualified 1/10MHz,0.075 3/5', 'Diodes')
#
# ('0.3 PPM/YEAR/1.0_500#CO-200#C_Ox245SD29JL1ATFREQ,0.007%;Oscillators-2.121', 'Oscillators')
#
# ('SMT#THIN FILM-YES/100.0mV_1206:642.1ohm', 'Resistors')
#
# ('CHIP#CERAMIC-0.004µF 30.0uV_1.0_METALLIZED FILM#5.0%', 'Capacitors')
#
# ('5000.0:125.0µF-SMT#2917#SPECIAL CAPACITOR', 'Capacitors')
#
# ('232050.0MΩ/RNM1/2(100,1%):0603;0.75uW:YES', 'Resistors')
#
# ('ESR IS MEASURED AT 100 KHZ;1/10 285.0µF;2.87,Cap,POLARIZED', 'Capacitors')
#
# ('CAPACITANCE TOLERANCE IS 0.25PF 6.45e-06µF;500.0uV;e0 5.0%:GLASS,Glass Capacitors', 'Capacitors')
#
# ('YES-100.0kA#305.0/3550.0_Transistors#125.0', 'Transistors')
#
# ('FILM CAPACITOR,4.45mm/15.0%:176.0µF_2.5kV', 'Capacitors')
#
# ('3 L4.9XB3.9XH1.25 (mm)/L0.193XB0.154XH0.049 (inch)-1.8,10.0kV#7/8mA:9/5mm/50 OHM,FIlters:35.0kHz', 'Filters')
#
# ('500.0kV/2/1%;RECTANGULAR PACKAGE,5/5e-05µF;NO;GLASS-MIL-PRF-23269', 'Capacitors')
#
# ('7/2_S_YES:-74_BIPOLAR#144.0 CEPT PCM-30/E-1', 'Telecommunication Circuits')
#
# ('COMMERCIAL/GLASS FILLED POLYESTER_35.0-0.403 3', 'Connectors')
#
# ('4.065mm-5/6-17.6µF#2 POLARIZED_15.0%', 'Capacitors')
#
# ('OPTICAL FIBER,LOCKING,PANEL:GENERAL PURPOSE:6/3:50/125um;PLUG#0.45dB', 'Connectors')
#
# ('4/2/3.0;8.0nA-50-60HzHz#0.15_PLASTIC 3/9 MAGAZINE PACK', 'Filters')
#
# ('125.0°C-Cap:3/1µF#1/4°C-15000.0:2:TANTALUM', 'Capacitors')
#
# ('THROUGH HOLE MOUNT;830nm,0.117kA-6/3°C_2.15kV#-5.0°C;105.0mA', 'Optoelectronics')
#
# ('3.0%,Ceramic Capacitors/0.02µF,Cap/8/7%/CERAMIC,VJxxx0A;1xxKNCAR4X', 'Capacitors')
#
# ('MR,AEC-Q200;e0_2/5.15e-07µF/NG#0805;POLARIZED', 'Capacitors')
#
# ('5.006µF,Contact Factory for Multiples,10000.0,0603-2/7°C/-40.0°C', 'Capacitors')
#
# ('WRAPAROUND/Ceramic Capacitors_C0G 1.43mm 1.134µF 贴片电容_327.5uV', 'Capacitors')
#
# ('TANTALUM (DRY/SOLID) 15%;RATED AC VOLTAGE (V): 440,POLARIZED:4.825:SMT:3.401µF,2/5', 'Capacitors')
#
# ('Fiber Optics_1559.0nm-0.75,45.0;ADD/DROP MUX/DEMUX', 'Fiber Optics')
#
# ('POLARIZED;No,5/4;5.705mm:0.06_21.15µF-1407', 'Capacitors')
#
# ('0.445 9/6:0505-40.0kV 1185000.215GΩ#0.75MW', 'Resistors')
#
# ('400.0mV_PAPER#-55.0°C;125.0°C_Paper Capacitors_TUBULAR PACKAGE,0.735µF', 'Capacitors')
#
# ('0.15mA;250.0kV-BRASS,TRAY:6/Rotary Switches#SPLASH PROOF BUSHING SEALED,SP3T', 'Switches')
#
# ('14.6mm,1.63Ω;3.0%#MIL-R-22684 38.099mm;WIRE:METAL FILM-2.875GW', 'Resistors')
#
# ('0.276inch-1.0kA;NO#2.54mm/CABLE#Connectors', 'Connectors')
#
# ('1/6-0.55%;310135.0Ω;Resistors#5.08:0603 SURFACE MOUNT', 'Resistors')
#
# ('5/7_NO;xH-C0565N30A3V13-5/1mm#0.502µs:DIGITAL VOLTAGE/4-WIRE INTERFACE_0.50-4.50V', 'Sensors/Transducers')
#
# ('NO-PAPER_105.0°C 400.0mV-0.523µF,2', 'Capacitors')
#
# ('D55342:贴片电阻_665.007kΩ;E/H(T-LEVEL)-TR 50ppm/°C,0.55%', 'Resistors')
#
# ('7/4mA-46.0mΩ#1060.0mA_Axial,THROUGH HOLE MOUNT,50.0kV/ALUMINUM (WET),16502.35µF', 'Capacitors')
#
# ('0.5mW_res;7/1%-Axial_10/3 235019.5R#2309,TUBULAR PACKAGE:Cylindrical', 'Resistors')
#
# ('FEMALE;ALUMINUM ALLOY:STANDARD: MIL-DTL-38999, COMPATIBLE CONTACT: M39029/56-351-2.219;25', 'Connectors')
#
# ('24.0 4/3°C#NO-5.0uV,2.54mm/4/8-9/9mm;4/2°C', 'Microcontrollers and Processors')
#
# ('FIXED RESISTOR 0.55%;-55.0°C,SURFACE MOUNT#THIN FILM Resistors_137.5°C;40600.0ohm', 'Resistors')
#
# ('3.5%;4.7,2#0.6W,AEC-Q200 340.12GΩ', 'Resistors')
#
# ('Special Capacitors,RECTANGULAR PACKAGE#8900.0_NIOBIUM:4.25uV-363.5µF-NBSA10xM00x;LBLC0724 电容', 'Capacitors')
#
# ('NOT SPECIFIED#9.0ps-DIP,COMMERCIAL', 'Consumer Circuits')
#
# ('Resistors_900900.0R 8739-METAL OXIDE FILM,200ppm/°C;NO/2/3mm 8/4', 'Resistors')
#
# ('2.4:AXIAL Non-linear Resistors_7/8#4.625_3.0:3118.0--10,10:RECTANGULAR PACKAGE', 'Resistors')
#
# ('-65.0°C#2888.5Ω/0.35MW:FHV_100;SURFACE MOUNT:155.0°C;METAL GLAZE/THICK FILM:e4', 'Resistors')
#
# ('2/4µF Capacitors X7R#15.0% 8;BULK-CERAMIC SMT', 'Capacitors')
#
# ('TAPE & REEL 179 OHMS 11000 OHMS/0.1 13.25kV/e3#147.5kV', 'Transformers')
#
# ('424.5MΩ;Tin/Lead (Sn/Pb);METAL FOIL:0603 SMT', 'Resistors')
#
# ('3.3V-DILCC6,.2_7/2#362.5MHz Vx-7#20-LFC-CAA-300.0000', 'Oscillators')
#
# ('TRIP FREE 6.65A#240.0uV-SHORT,-30.0°C-60.0°C/Protection', 'Circuit Protection')
#
# ('X-XXSS-X2 Telecommunication Circuits_BIPOLAR,NOT SPECIFIED#9/3', 'Telecommunication Circuits')
#
# ('REFERENCE STANDARD: AEC-Q200#9/9µF-POLARIZED 4750.0/J BEND/Cap', 'Capacitors')
#
# ('9/7µF_400.0mV-PAPER,Paper Capacitors CZR24', 'Capacitors')
#
# ('13.335#0.045µF_POLYPROPYLENE;B3x63x-A63_3x-K060_7035', 'Capacitors')
#
# ('7/8#0.75%#Fixed Resistors/71545.5Ω/0.163nW_RECTANGULAR PACKAGE', 'Resistors')
#
# ('6.7#METAL OXIDE FILM 3575.0,15.0/147.5uV-113.4#2/8;Non-linear Resistors', 'Resistors')
#
# ('2.75%/8-1.69kW#100ppm/°C#6/10-ARRAY/NETWORK RESISTOR:75.005K 3.715', 'Resistors')
#
# ('0805;WRAPAROUND;YES/3050.0R:100ppm/°C e0:1.435mm#0.228uW', 'Resistors')
#
# ('22.5-0.075#4/3#13.0_4 Switch', 'Switches')
#
# ('2,0603_125.0°C AR05#Tape, Paper_7960.0Ohm--55.0°C--25,25ppm/°C_0.081mW', 'Resistors')
#
# ('120.0,4/1:0.575 SINGLE/Diodes', 'Diodes')
#
# ('FIXED RESISTOR:8520-METAL ALLOY;603000.0ohm#70.0°C/-55.0;155.0:350.0mV;1.062pW', 'Resistors')
#
# ('CERAMIC,5/7%;Yes-1.1µF WRAPAROUND_227.0mA', 'Capacitors')
#
# ('27.5uV_TANTALUM/T83_24.0µF#No/950.0 SURFACE MOUNT', 'Capacitors')
#
# ('7/6°C 480.0#2.0-4/10;70.0°C-Displays', 'Optoelectronics')
#
# ('1#BULKHEAD-BULKHEAD/FEMALE:65.0;e4-Connectors', 'Connectors')
#
# ('2020-TANTALUM CAPACITOR;28.0kV,2,2/6µF', 'Capacitors')
#
# ('CERMET/5/10%/11.25#260000.0MΩ,e3', 'Resistors')
#
# ('1/7-5/1;-10,10-METAL OXIDE FILM;2/2#CxF_D103H3650HDNT;MIL-PRF-32192', 'Resistors')
#
# ('4/10#NO_350.0 3-WIRE INTERFACE/CONNECTOR#AEC-Q100 NOT SPECIFIED', 'Sensors/Transducers')
#
# ('R-PSSO-G2;19.0uA#3.0_1.0-24.65#NOT SPECIFIED:Transistors:200.0', 'Transistors')
#
# ('1.05#600.0/0.9pW-SILICON:2:LOW NOISE;0.6', 'Diodes')
#
# ('5.0%#3495.0R,0805:Mx5x5K33_x2GBW:SMT M2512(GJTOL)', 'Resistors')
#
# ('Paper Capacitors:300.0mV,TUBULAR PACKAGE,PAPER 0.134µF', 'Capacitors')
#
# ('D55x42H07B1H2-0TTI:0.546mm,3.2mm-1170000.0GΩ THIN FILM;M55342;0.1%', 'Resistors')
#
# ('CBB02072%Cx9x,K;0.425MW LASER TRIMMABLE:2550255.0O:贴片电阻_CARBON FILM', 'Resistors')
#
# ('贴片电阻-105.0,0805_1281.5/7/6J/-10,10-17.0-2/7', 'Resistors')
#
# ('11.0 Not Qualified/Diodes#0.125W 2/6:1.1:ROUND', 'Diodes')
#
# ('WIRE-xK202070A1102JD,5:5.5%:5.263kΩ 200ppm/°C/Axial,METAL OXIDE FILM', 'Resistors')
#
# ('150.0MHz#112.5,2.8 95.0_ENHANCEMENT MODE', 'Transistors')
#
# ('7/16 FEMALE,LTF3216D_e4:2.85mm/1.7dB,1.9', 'Filters')
#
# ('MALE_2/Two Part Euro Connectors/RECEPTACLE 2.54mm/94V-0', 'Connectors')
#
# ('17.5ppm/°C_12.45V;1.0:0.1nA:8/2%', 'Power Circuits')
#
# ('R-PDSO-G8:3/3:13.5V-YES#BIPOLAR/RECTANGULAR:AUTOMOTIVE', 'Signal Circuits')
#
# ('Metal Alloy Resistors/155.0 10.002kΩ-Fixed Resistors,25:0.425GW:-55.0#METAL ALLOY', 'Resistors')
#
# ('INDUSTRIAL,Signal Circuits 6/8°C/CURRENT-MODE/97.5°C:117.5ns#2/6,GND/-6V:394.0ohm', 'Signal Circuits')
#
# ('0.45mm,0.081mW-0.1%_7960.0MΩ_SMT;3/4mm Fixed Resistors;0603', 'Resistors')
#
# ('CMR;0.0µF-MICA:THROUGH HOLE MOUNT/25+/-25ppm/Celppm/°C_29xx0E47xJ0-2;/3112#500.0mV', 'Capacitors')
#
# ('STABISTOR DIODE#ROUND_2.0#7/3 0.01:SILICON', 'Diodes')
#
# ('Tin/Lead (Sn/Pb):2/6,DIP16,.3#11.0/4.5_#xAC1265AJ/883B;1.5#Other Converters', 'Converters')
#
# ('Microwave#DIE OR CHIP#29.5:4/5;28.495dBm-50.0', 'RF and Microwave')
#
# ('1.9mm/20.0%#6/6mm_1411 SMT-47.0µF/5.4mm;NIOBIUM OXIDE', 'Capacitors')
#
# ('Paper Capacitors/0.47µF#300.0V--55.0°C-5/6°C,Capacitors PAPER,THROUGH HOLE MOUNT', 'Capacitors')
#
# ('Digital Signal Processors/2/5,2.844uV 70.0MHz:0.0 2.75V', 'Microcontrollers and Processors')
#
# ('CMOS#TSSOP#COMMERCIAL EXTENDED,4/1_3.15_1.004,BOOST#1.95uV', 'Power Circuits')
#
# ('WIRE WOUND_0.275%/2/RS,RS#FIXED RESISTOR 4.847Ω;6927', 'Resistors')
#
# ('5.0%_550.0uV-2.55e-05µF:70ppm/Celppm/°C/2/电容_1210;CDS19', 'Capacitors')
#
# ('3/6mA;10/1%-2650.0/SMT:17.6µF/2225,15%', 'Capacitors')
#
# ('SQUARE#50.0mΩ#0.5,8.75dB/2/6dBm/RF/Microwave Mixers:YES,13', 'RF and Microwave')
#
# ('10.0%;SURFACE MOUNT_1.19µF#1.885#3650.0_6.15uV;ESR IS MEASURED AT 100 KHZ', 'Capacitors')
#
# ('0.6dB#125um_PLUG,连接器 8011', 'Connectors')
#
# ('28.0:Tin/Lead (Sn/Pb) - with Nickel (Ni) barrier:25ppm/°C_9/4% 4918.4Ohm -55.0°C-0805:6/1°C_3/6', 'Resistors')
#
# ('7960.0O#-55.0°C,-25,25ppm/°C:SMT:0.062W#TANTALUM NITRIDE/NICKEL CHROME;FIXED RESISTOR', 'Resistors')
#
# ('0.013kΩ;170.0°C-0805 0.5GW/75ppm/°C/Res SMT#Matte Tin (Sn) - with Nickel (Ni) barrier', 'Resistors')
#
# ('No:2#0.195µF#625.0mV:Film Capacitors POLYPROPYLENE', 'Capacitors')
#
# ('3 PPM/YEAR-2/4°C:30.0ppm;AT CUT; TRAY 0.003% 52.999MHz 4/8°C,505.0µW', 'Crystals/Resonators')
#
# ('4.855mW_RADIAL:4/8% 34028.0R_Resistors;195.0', 'Resistors')
#
# ('1.0%:FIXED RESISTOR:NO 4.445:183.905Ohm:Res-METAL FOIL 25.4#3011', 'Resistors')
#
# ('65.0:865000.0#3000.0;0.975:0.075µs', 'Diodes')
#
# ('3.55mm,1411/TR, 13 Inch/NIOBIUM OXIDE#5/7µF#10.0%;SMT', 'Capacitors')
#
# ('NIOBIUM OXIDE 2.675mm 84.0µF#1411;-55.0°C 125.0°C;15.0%', 'Capacitors')
#
# ('166.88mΩ/METAL FOIL HIGH PRECISION, NON-INDUCTIVE-300.0uV_3.05,xTxG1506374,R00DW:0.15% 0.8mW', 'Resistors')
#
# ('CERAMIC/5.0uV 3/7#5-NO/5962x01x204/x2883', 'Memory')
#
# ('Resonator,TAPE AND REEL-DxD036;BN016A:Dielectric Resonators', 'Crystals/Resonators')
#
# ('1421.5nm/1/10nm C-_15-xx1-RB-SFCHI-GR,1281.0nm,4/4', 'Fiber Optics')
#
# ('4/8dB_SC/APC CONNECTOR_GR-1209, GR-1221-1390.0nm#ALSO OPERATES AT 1490NM WAVELENGTH:8/1nm-1475.0nm-52.5 1X2', 'Fiber Optics')
#
# ('3011;196.5R;5.715 SMT/4.394:70.0°C/MIL-PRF-55182_2ppm/°C/0.55%', 'Resistors')
#
# ('0805 FLAT-RATED AC VOLTAGE (V): 1-X7R-ARRAY/NETWORK CAPACITOR_0.02µF', 'Capacitors')
#
# ('Tin/Lead (Sn/Pb) - hot dipped/4.4uV:REFERENCE STANDARD: AEC-Q200 20.0%-电容:SURFACE MOUNT POLARIZED:400.0µF', 'Capacitors')
#
# ('METAL OXIDE FILM#NT73#5.75#3535.0-RECTANGULAR PACKAGE 109.1', 'Resistors')
#
# ('贴片电容,xZR24BKF224M_,4/6µF#Paper Capacitors/400.0kV PAPER CZR23', 'Capacitors')
#
# ('5/6°C,16000.0GΩ;10/4:3/1°C;0.167nW;DISK PACKAGE;WIRE', 'Resistors')
#
# ('0.6nW/MVW-0.132O;NO#9.52mm;2.0%', 'Resistors')
#
# ('92.5:BICMOS 3.9dB:THROUGH HOLE MOUNT-Microwave-50.0O#YES_1.335', 'RF and Microwave')
#
# ('Chip/2:2.55%-605007.35GΩ-50ppm/°C', 'Resistors')
#
# ('WIRE WOUND:TUBULAR PACKAGE_Resistors_0.171K/MIL-PRF-39007#90ppm/°C', 'Resistors')
#
# ('32.05mΩ 0.5uW-电阻-250.0uV,0.75%,THROUGH HOLE MOUNT,RNR', 'Resistors')
#
# ('NO,-65.0°C-NOT SPECIFIED;140.0°C', 'Transistors')
#
# ('1466.0,e0,WRAPAROUND_Non-linear Resistors_NCT08 METAL OXIDE FILM,2.55-0.2', 'Resistors')
#
# ('0.03-496:NO/THERMOSET,1', 'Connectors')
#
# ('2;15.0% WIRE-Axial-4/5mΩ:17.5mV_35.1µF', 'Capacitors')
#
# ('FLAT_YES 6.25A/10.5 260.0', 'Transistors')
#
# ('NTCG16_385.5-RADIAL;2.5;0805', 'Resistors')
#
# ('7.14;Rectangular 4527:1651.62R;Axial 10.0W;res-50ppm/°C', 'Resistors')
#
# ('3/4µF:MIL-PRF-55365,105.0°C:NIOBIUM OXIDE#Other Capacitors/xBJC107M1R_8CRSB0800/-55.0°C,20.0%;1411', 'Capacitors')
#
# ('-22.5°C_2_125.0°C/8/2MHz-31.5_1.31', 'Inductors')
#
# ('5.0mV/2917-5.4mm#NBS,330.0µF 7.5:POLARIZED', 'Capacitors')
#
# ('-82/+22%ppm/°C_2.35µF:0805:15.0%,ARRAY/NETWORK CAPACITOR-SMT', 'Capacitors')
#
# ('30.0uV/Consult Factory_0.06;SMT/10/5#7.735µF', 'Capacitors')
#
# ('156795.0/1000.0_SURFACE MOUNT_T-795_0.125,1.25,13.22mm', 'Transformers')
#
# ('55.0ns,200.0-4/3,ACTIVE DELAY LINE,5.0mV,12.065:TUBE-1100', 'Logic')
#
# ('PERCENTAGE TOLERANCE ON C_MAX IS 0/+100#538 VIL3/4.25e-0;NP0 CERAMIC-75.0,1/7', 'Capacitors')
#
# ('8/3e-05µF;1206:75.0uV/RATED AC VOLTAGE (V): 1:C14x7;51JY5V5 CERAMIC 105.0°C:-55.0°C', 'Capacitors')
#
# ('276.5mΩ_8/4µF-贴片电容,20.0%/IEC60384-4 TUBULAR PACKAGE:ALUMINUM ELECTROLYTIC CAPACITOR_4141', 'Capacitors')
#
# ('No/4.4uV,27.5µF:TR, 13 INCH_10300.0/SPECIAL CAPACITOR-20.0%', 'Capacitors')
#
# ('92.5 10.0_G,MA7975CA_16.0Pixel:566;-40.0', 'Optoelectronics')
#
# ('9/9µF,2.15mV SMT/10.0% 15.0%', 'Capacitors')
#
# ('10.0% R75#WIRE 175.0uV#4916#Capacitors#0.005µF', 'Capacitors')
#
# ('0.425mW-25/1/1mm;4750000.0Ohm TR,FIXED RESISTOR#0.055%', 'Resistors')
#
# ('0.064% PARALLEL, WORD/5.1kV,7/4MHz#PLASTIC/EPOXY_DUAL', 'Converters')
#
# ('e4_5/STAINLESS STEEL RECEPTACLE-RECEPTACLE#MALE-MALE:Connectors:PANEL', 'Connectors')
#
# ('PLASTIC/EPOXY-CMOS/FLATPACK, LOW PROFILE;3.3_QUAD', 'Telecommunication Circuits')
#
# ('BICMOS,1#5.0kV,85.0°C#CEPT PCM-30/E-1', 'Telecommunication Circuits')
#
# ('GLASS_M23-269/01x122,400.0kV/5/6e-05µF +140+/-25ppm/Celppm/°C', 'Capacitors')
#
# ('1.0A;NO#250.0mV;0.1A_PHOTO TRIAC DRIVER', 'Optoelectronics')
#
# ('4.45e-07µF_17.5kV_1.025mm_RECTANGULAR PACKAGE,1206-VJ', 'Capacitors')
#
# ('3.9V,4.357uV:1 PPM/FIRST YEAR,MIL-PRF-55310 Class B:TCVCXO-10000Ω:28.096MHz:2.55kV', 'Oscillators')
#
# ('0.475mm:0805#0.081kW-xR05BTC7961,#电阻:-25,25ppm/°C#3.985mΩ;AR03-2', 'Resistors')
#
# ('27.5%:0.111µF#Fixed Capacitors;CERAMIC:Radial-X7R/150.0V', 'Capacitors')
#
# ('8/3/15.65:0603 10/9;7/4', 'Resistors')
#
# ('9/2°C#45.0ms_155.0°C-257.085ohm,Resistors;0.55kW', 'Resistors')
#
# ('50000000.0/50.006µF#1206#11.0%/280.0#6.965%#THROUGH HOLE MOUNT 100.0V', 'Capacitors')
#
# ('3.053kV#2.9kV#Voltage Controlled Sine SAW/STW Oscillators_8/4-1.0#e4-3.547kV', 'Oscillators')
#
# ('3#4/5/6.0_12.583Mbit_内存,11.6mm', 'Memory')
#
# ('1.0ms#3.4#2.75%,-55.0°C:FMR(0.1-10K);0.945Ω', 'Resistors')
#
# ('2/9:DISK PACKAGE-0.121MW,10.0/26900.0MΩ#3943.5:4.0%/Radial', 'Resistors')
#
# ('SMT/ESR IS MEASURED AT 100 KHZ-9/6µF:15.0%-TR, 7 INCH 12000.0', 'Capacitors')
#
# ('9/8µF:13.0V;e0;CERAMIC;Matte Tin (Sn) - with Nickel (Ni) barrier:TR, EMBOSSED/PAPER, 7 INCH', 'Capacitors')
#
# ('0.687µH_19.823µH,Inductors/278.0µH-105.0°C;FERRITE -47.5°C_PCB Mount,VARIABLE INDUCTOR', 'Inductors')
#
# ('14.85_1;7871_100.0°C#500.024kΩ LINEAR/HORIZONTAL#CERMET', 'Resistors')
#
# ('Fixed Resistors#0.014ohm;1.0%,0.5GW:Metal Strip/Wire Resistors', 'Resistors')
#
# ('Tin/Lead/Silver (Sn62Pb36Ag2)#METAL GLAZE/THICK FILM_1010_1105.422Ohm-SMT;res', 'Resistors')
#
# ('0.004;0.55-2.45/1.01/LOW LEAKAGE_3 0.715', 'Diodes')
#
# ('2020.0Ohm:45.0s Cylindrical#METAL FILM-WIRE#0.55nW/Tin (Sn) - with Nickel (Ni) barrier', 'Resistors')
#
# ('6000.0-POLARIZED#2/SMT NIOBIUM 400.0µF;J BEND', 'Capacitors')
#
# ('0.365;0.275%-6.31mm_Resistors,SURFACE MOUNT/150.0kΩ;THIN FILM', 'Resistors')
#
# ('T-3(DS3):16.0,246120.0#0.975,8.0mm', 'Telecommunication Circuits')
#
# ('1206#1/2 Capacitors POLARIZED-MIL-PRF-55365/80.0µF 10/4;2.95mm;Cap', 'Capacitors')
#
# ('NO 38750.0MHz#14.5mV 4/2MHz;5.0kV,5.5', 'Oscillators')
#
# ('Capacitors#PAPER CAPACITOR#10/5µF;400.0kV/NO_2:PAPER', 'Capacitors')
#
# ('PLATINUM_-50.0°C-Sensors;2-WIRE INTERFACE TEMPERATURE SENSOR,RTD,PLATINUM/YES:1000.0Ohm', 'Sensors/Transducers')
#
# ('475.0_NP0-Capacitors#THROUGH HOLE MOUNT,3.0pF TSW,4.3e-0 1816', 'Capacitors')
#
# ('YES#N-CHANNEL#3/2:DEPLETION MODE/Not Qualified:1/7;0.03,MATTE TIN', 'Transistors')
#
# ('7645.0R-1206:1.27 70.0°C:METAL GLAZE/THICK FILM;SMT#100_Fixed Resistors', 'Resistors')
#
# ('PROXIMITY SENSOR,INDUCTIVE_2.5mm PLASTIC/EPOXY#3-WIRE INTERFACE-109.525mm:NO', 'Sensors/Transducers')
#
# ('0.188kW,-55.0°C_TR:CARBON COMPOSITION_1968.0O', 'Resistors')
#
# ('TIN LEAD_MICA;0.0µF_Radial_6113', 'Capacitors')
#
# ('25.4mm,METAL ALLOY-SPUOPENSTYLE:5;5.08_0.004MΩ;8520/5/9mm-Cylindrical', 'Resistors')
#
# ('CERAMIC/0.0;NP0 e3-6.5e-0/4.75pF/TR, 13 INCH 137.5', 'Capacitors')
#
# ('100#0.0O#2/3°C/RCWP,51xxxxxxZSEA99 TR, Plastic, 7 Inch-METAL GLAZE/THICK FILM:1/5', 'Resistors')
#
# ('NPQ_FLAT 2.1e-05-VERTICAL;CERAMIC', 'Capacitors')
#
# ('75.0uV#-55.0°C:0805#3985.0O-9/4mm:电阻#5/10°C;TANTALUM NITRIDE/NICKEL CHROME', 'Resistors')
#
# ('15.0%,CERAMIC:1/9e-05µF Capacitors/THROUGH HOLE MOUNT', 'Capacitors')
#
# ('CHASSIS MOUNT#xZR24BKE,474M/CZR23_PAPER_400.0V_NO#0.285µF', 'Capacitors')
#
# ('410.0_110.0-87.515 10.0;4/2_UPPER#2.0-9.2mm', 'Consumer Circuits')
#
# ('1.25_JACK,FEMALE_1.75_THREADED;.556-BRASS UL, CSA', 'Connectors')
#
# ('600.0/399.58mm,6/9kHz#1/5/CURRENT TRANSFORMER/-35.0:2/3kHz', 'Transformers')
#
# ('2/4°C,SMT:2412#6.3V#100.0µF', 'Capacitors')
#
# ('1/1°C_Fixed Resistors 2.625%-59000.007GΩ-5044:贴片电阻', 'Resistors')
#
# ('26790.0-1.3uV_1.43ns_3.0uV/2.265kV 5/6MHz:BGA301,21X21,20-222.5', 'Programmable Logic')
#
# ('2/7 120.45kΩ_DISK PACKAGE-100.0°C TEMPERATURE COMPENSATION,-7.5°C_2.5%#147.5_0.312W', 'Resistors')
#
# ('2.035:27.5uV_TANTALUM (DRY/SOLID),4.065mm 9250.0-13.35µF/xWR06N#H154JDA/TR/RECTANGULAR PACKAGE', 'Capacitors')
#
# ('TP(1KV)CA-GEB-75.0-Tape & Reel Available,电容 0.0 9.015;5/4 4.25e-06/CERAMIC', 'Capacitors')
#
# ('FIXED RESISTOR/2.085;2.015#METAL FILM#4527#460.5Ohm 25ppm/°C', 'Resistors')
#
# ('Cap/0.0µF#3.5%/GLASS:CAPACITANCE TOLERANCE IS 0.25 PICO FARAD:e0/GLASS CAPACITOR#500.0V 2', 'Capacitors')
#
# ('3.5pW;21.949Ohm_WIRE WOUND,e3;8737_CPR-SPECIAL TERMINAL;Wire Wound Resistors', 'Resistors')
#
# ('57#12.605mm,1.0:Pulse/Datacom Transformers/0.9', 'Transformers')
#
# ('512.5,NP0#0.0:4.25e-06#FLAT', 'Capacitors')
#
# ('-6.0#4.15mV:Signal Circuits;4.4 5/6-GULL WING-10/4-1.78mm;信号电路', 'Signal Circuits')
#
# ('Resistors,CARBON COMPOSITION/55500.0ohm_WIRE;300.0mV/625; 1125; 1375; 1750; 2500', 'Resistors')
#
# ('ALUMINUM (WET),0.557mA 4/5mΩ-93400.0µF_IEC60384-4', 'Capacitors')
#
# ('4/5mΩ:341.95µF:217.5uV,Matte Tin (Sn),NO', 'Capacitors')
#
# ('5/7°C Metal Foil Resistors#0.17GW-2512,SMT,17215.0Ω--60.0°C', 'Resistors')
#
# ('42.727-IF Transformers-2000 OHMS-105.0--40.0-IF TRANSFORMER', 'Transformers')
#
# ('电容;1/4%/CERAMIC:3.402µF:Tin/Silver/Copper (Sn/Ag/Cu);MA:1/3mm', 'Capacitors')
#
# ('POLARIZED ALUMINUM (WET):7/4,523.5µF/056PSM-SI 4.25', 'Capacitors')
#
# ('Photo Transistors,5.0_e0 5/9/900-ROUND', 'Optoelectronics')
#
# ('3/7-0.37W;880.0Ohm-YES,AEC-Q200', 'Resistors')
#
# ('12.0#92.5:1.985,50.0Ohm_1-7/10dBm-8/7MHz-2251.0MHz:-55.0', 'RF and Microwave')
#
# ('3.0%-Chip;2765.0ohm -100,100ppm/°C;M0502-0505(FTOL)', 'Resistors')
#
# ('贴片电容;TANTALUM:2.5:22.5uV/10/4/4/5µF:e4', 'Capacitors')
#
# ('FIXED RESISTOR_电阻-MATTE TIN/100ppm/°C-METAL OXIDE FILM Chip;0.6kW/978.0K/2', 'Resistors')
#
# ('5.0kV#UNSPECIFIED_Telecommunication Circuits 1/5#AEC-Q100;2.0', 'Telecommunication Circuits')
#
# ('6363-e3;235.1K#-150,150-7/9#20.0%#HORIZONTAL#Matte Tin (Sn)', 'Resistors')
#
# ('-30.0°C#425.0mA:CHASSIS MOUNT Fixed Gunn Oscillators/9/7MHz', 'Oscillators')
#
# ('-55.0°C#AR0xBTC/10R0-0.1MW;2.0mm-0603 3.985mΩ;TANTALUM NITRIDE/NICKEL CHROME#0.5mm#1/1°C', 'Resistors')
#
# ('400.0V:-250ppm/Cel:0.019µF:6920;8/8mm 2/9:TR, 20 INCH/NON-POLARIZED', 'Capacitors')
#
# ('YES/CRHV,MIL-PRF-55342,res 3246.1MΩ,3.0% 1206,METAL GLAZE/THICK FILM', 'Resistors')
#
# ('Gates/10/10 NO/Logic#5.0kV', 'Logic')
#
# ('MA/1206;Tin/Lead (Sn/Pb) - with Nickel (Ni) barrier,Array/Network Capacitors;CERAMIC;1.1µF:100.0kV', 'Capacitors')
#
# ('6/7-5V/-47.5°C 50000.0#5.0mV,4/7-9/2°C_1876.4V:5/10', 'Amplifier Circuits')
#
# ('0805 10/5°C#8/9,0.012ohm-Metal Strip/Wire Resistors 75ppm/°C_0.5mW', 'Resistors')
#
# ('THROUGH HOLE MOUNT#125.0°C-GLASS-300.0V:Capacitors/0.0µF-1/5°C#3.0%', 'Capacitors')
#
# ('5 5.0uV,VOLTAGE-MODE:-5.0 7.938mm-19.5GHz-Signal--15.0:14.465', 'Signal Circuits')
#
# ('2/1:1.398-CABLE,1.22/LOCKING-1,NOT SPECIFIED 500.0', 'Connectors')
#
# ('.1946_2;8.0_D Type Connectors_2_RND PIN-SKT', 'Connectors')
#
# ('SMA FEMALE CONNECTOR_Oscillators/5/7:1.0kHz#7775.0', 'Oscillators')
#
# ('5.0-38.55mV 144.25 4/6_AVALANCHE_48.05kV:0.014', 'Diodes')
#
# ('1.0#10/Not Qualified -30.0°C/85.0°C/4.15uV 9/9MHz', 'Oscillators')
#
# ('3009.0-1/7µF TR, PAPER, 7 INCH/POLARIZED;Fixed Capacitors', 'Capacitors')
#
# ('2/7;6/9;1.5%_0.2uW_贴片电阻 528500.0ohm_Resistors_RECTANGULAR PACKAGE', 'Resistors')
#
# ('85.0°C Displays/5.0mV/16.0:3/5', 'Optoelectronics')
#
# ('Capacitors_CERAMIC#PCB MOUNTABLE, 10 TURNS/5/4e-05-cap/30.0', 'Capacitors')
#
# ('N FEMALE#PANEL MOUNT/REMOVABLE SMA-3000.0MHz L50.55XB16.8XH12.7 (mm)/L1.99XB0.661XH0.5 (inch)#1.5 3', 'Filters')
#
# ('28.0#5.08-2.55%,1600.0Ω#0402 Resistors', 'Resistors')
#
# ('0.175GW;0.75%_-65.0°C 27282.5O;38.1#6/6/4/1', 'Resistors')
#
# ('GLASS,TSR;6/5pF_2.05e-06-3/4pF/NP0_55.0', 'Capacitors')
#
# ('Resistors:CERMET_7563#11050.0GΩ Matte Tin (Sn)_0.75kW 1.1,P11P', 'Resistors')
#
# ('SURFACE MOUNT,2.616mm:Resistors#0.125kW/WRAPAROUND;1085000.0R;0.546mm,THIN FILM;50ppm/°C', 'Resistors')
#
# ('8.0:2.0,29.74MHz#e4_FLASH;GENERAL PURPOSE ZPLD, DECODING ZPLD & PERIPHERAL ZPLD', 'Microcontrollers and Processors')
#
# ('10/5°C/THIN FILM,TR, PUNCHED PAPER, 7 INCH:143600.0ohm;0.75% -55.0°C', 'Resistors')
#
# ('3/2:4.0_2.775-0603:23.0,-47.5/34.5/3795.0/YES:Non-linear Resistors', 'Resistors')
#
# ('0.838mm#240.5Ω--100,100ppm/°C_SURFACE MOUNT,METAL GLAZE/THICK FILM-RECTANGULAR PACKAGE,3.0%#Chip;1.397mm', 'Resistors')
#
# ('0.15kW#240.0°C/11656.0O,5.715;0.639_-55.0°C-4.46/0.135%', 'Resistors')
#
# ('4.5e-07_1.7kV#8/3°C/10/3mW#0.04/3/6e-0-2/3°C-GaAlAs,0.075A', 'Optoelectronics')
#
# ('0705/D55342H0,xB1H00TTS 735007.25MΩ_YES;TR#50ppm/°C FIXED RESISTOR:0.125pW', 'Resistors')
#
# ('NO:Paper Capacitors:电容-300.0mV;125.0°C/9/8°C_0.074µF;PAPER:C;ZR23BEF4x3M', 'Capacitors')
#
# ('3.16%#125.0°C_275.0V,-55.0°C GLASS_Axial_4/6mm;4.55µF', 'Capacitors')
#
# ('THROUGH HOLE MOUNT,4/10%,175.0mV#-55.0°C;95.0°C:7/8µF;WIRE#POLYPROPYLENE', 'Capacitors')
#
# ('85.0/-40.0 125um:NO;0.2;1', 'Connectors')
#
# ('RK1413G:LINEAR/6350_3_Matte Tin (Sn)_1.35,-150,150#16000.0GΩ', 'Resistors')
#
# ('3/3e-05µF-9/8mm#1206#-82/+22%ppm/°C/SMT_CERAMIC', 'Capacitors')
#
# ('5.4mm;2.8mm;2/2%;Other Capacitors_1411,Capacitors#258.5µF_cap/NIOBIUM OXIDE', 'Capacitors')
#
# ('NO,FLOATING-POINT_5#DSP Peripherals/Processors_32.0,6/9', 'Microcontrollers and Processors')
#
# ('VSMP:3/6 0.13%#Gold (Au)/3/10_1.544kΩ/METAL FOIL:2512', 'Resistors')
#
# ('2.5uV;SMT;NIOBIUM OXIDE-85.0°C_-55.0°C,Capacitors-15.0% 4/3mm 5/6µF', 'Capacitors')
#
# ('300.0V 0.074µF_MIL-C-11693/7/NO#PAPER', 'Capacitors')
#
# ('155.0°C_0.5mA/-60.0°C/Trigger 125.0A;1.7_Other Trigger Devices', 'Trigger Devices')
#
# ('NOT SPECIFIED:5.0V/YES_8.0,Microcontrollers:Tin/Lead (Sn/Pb)', 'Microcontrollers and Processors')
#
# ('BLACK/WHITE-COPPER ALLOY#DPDT#SILVER;9/4 8.0,NYLON', 'Switches')
#
# ('1500/1.95kΩ#SMT#2.0%,CYLINDRICAL PACKAGE;BULK-1406;Matte Tin (Sn) - with Nickel (Ni) barrier', 'Resistors')
#
# ('0.55%#WRAPAROUND-2:THIN FILM_27715.0GΩ#28.0 0.2kW 5.08', 'Resistors')
#
# ('108250.0GΩ;THIN FILM-0.15pW;YES#FIXED RESISTOR#75.0uV:50ppm/°C', 'Resistors')
#
# ('565.0kΩ-e3/1.0mW-NO,8520', 'Resistors')
#
# ('LLDx3SEL_#28.5-Not Qualified:127.5kV/30.0uV', 'Trigger Devices')
#
# ('5.25pW_FIXED RESISTOR/8739,Tin/Lead (Sn/Pb):50ppm/°C;1425000.0Ohm;WIRE-205.0°C/-55.0°C', 'Resistors')
#
# ('MIL-PRF-55365#15.0%;FILM CAPACITOR_NIOBIUM OXIDE#550.0µF/15.0%;Waffle Pack 2.15kV', 'Capacitors')
#
# ('52.5dB-1595.0nm 1/5nm_NOT SPECIFIED:FC/UPC CONNECTOR:0.75', 'Fiber Optics')
#
# ('0.55%/-60.0°C/3.315Ohm:BULK 250.0°C:WIRE WOUND-1.5mW/Resistors-FIXED RESISTOR', 'Resistors')
#
# ('308.0V/9/8,170.0-YES;3/1µF', 'Capacitors')
#
# ('FME, BANDWIDTH : 45 MHZ;LOS:2100.0,1.2:9/8:#ALP4Lx-HSW-x6#20.445dB:2.155mm', 'RF and Microwave')
#
# ('2/10µF_VJ OMD-C0G/CERAMIC CAPACITOR:-55.0°C#850.0mV-C0G 125.0°C,1210', 'Capacitors')
#
# ('Other Interface ICs-3/3°C_AEC-Q100/SEGMENT,2.55 2.15:-40.0°C/STANDARD_CERAMIC', 'Drivers And Interfaces')
#
# ('15.0%#10/10-5/7µF:20.0%-贴片电容#YES 7/7mm', 'Capacitors')
#
# ('WRAPAROUND_12.75mm;1586.0MΩ_3.0%-YES 1010,1.205-50ppm/°C', 'Resistors')
#
# ('TIN LEAD_5/10%/C0G/NCA--55.0°C#1.111µF:CERAMIC', 'Capacitors')
#
# ('28000.235µF-275.0mV/Aluminum Electrolytic Capacitors 8/1mΩ-2435.0mA AMMO PACK#2-35.0%', 'Capacitors')
#
# ('SURFACE MOUNT#NO_8/2mm 7500.0Cycles:0.5uA_PCMCIA Connectors 4-NO', 'Connectors')
#
# ('1;502136:500um/NO,GENERAL PURPOSE;1000.0-1.5dB:#800xx9G027', 'Connectors')
#
# ('0.062mW#SMT_10.0O#Resistors#Resistors/TANTALUM NITRIDE/NICKEL CHROME', 'Resistors')
#
# ('3/10%;xMB02070X6-803JB200:1500255.0ohm_e3;CARBON FILM_SMT', 'Resistors')
#
# ('连接器,CABLE/7 MALE#RECEPTACLE/ENVIRONMENT RESISTANT/ALUMINUM ALLOY,NO;9/1', 'Connectors')
#
# ('5.49,1/2e-05#1412#SMT 75.0', 'Capacitors')
#
# ('xx-xx383408xx 1.117µF#4/2%#NON-POLARIZED-FLAME PROOF, RATED AC VOLTAGE (V): 900', 'Capacitors')
#
# ('MIL-PRF-81-4.25e-06;CERAMIC,4.375/3.15;VARIABLE CAPACITOR:5.5 425.0', 'Capacitors')
#
# ('0.0µF#6/6%,2,GLASS_WIRE_e4', 'Capacitors')
#
# ('DO-35:0.475pW/1.35uV-SILICON-1/5mA,Current Regulator Diodes;650000.0', 'Diodes')
#
# ('9.0-40.0_3/4;10.5K#3925.0_2.65_0.312MW_RADIAL,2.0%', 'Resistors')
#
# ('CBB 0207/Resistors,1/3/0.425W 54.5K,2/9,1500,3.5%', 'Resistors')
#
# ('500.0mV 7/10µF/Glass Capacitors/GLASS,贴片电容 6/3%_Capacitors,125.0°C,1/1°C', 'Capacitors')
#
# ('2/5%:GLASS/300.0mV-CAPACITANCE TOLERANCE IS 0.25PF#0.9µF-Axial/3.58mm', 'Capacitors')
#
# ('1206-MA/WRAPAROUND/20.5uV/SMT,Y5V,3/3µF-ARRAY/NETWORK CAPACITOR', 'Capacitors')
#
# ('45.0µF;e0-6000.0 2.4_SMT 2412,NIOBIUM', 'Capacitors')
#
# ('Interfaces#8.5#4.0:CD MOTOR DRIVER;5.0kV#5.5kV:2A', 'Drivers And Interfaces')
#
# ('电阻 5.0% -40.0°C;PRECISION:550000.0ohm:Resistors_1412', 'Resistors')
#
# ('YES e0:0.001,T-1(DS1)-3.3mV-1168.0', 'Telecommunication Circuits')
#
# ('8.65,MICA#0/+70ppm/Celppm/°C-5.0%_0.0µF/e0_BULK,100.0uV', 'Capacitors')
#
# ('NO,2.665%:300.0uV;3.58mm 电容-3.15e-05µF', 'Capacitors')
#
# ('3722.0 9/5%:DISK PACKAGE#Tin/Lead (Sn/Pb),5250.0GΩ', 'Resistors')
#
# ('WIRE_0.1%-0.225GW_METAL FOIL,6752.5R_Tin (Sn) RECTANGULAR PACKAGE 1.955', 'Resistors')
#
# ('45.0us-4/10mm:LCA0207SI-6.5mm:243.0K,1210', 'Resistors')
#
# ('50ppm/°C,3825-1.815mm_9713.5MΩ#THIN FILM;24/Resistors,SMT', 'Resistors')
#
# ('Resistors#0603#RNx6,0H9532BPRE6#3/3°C-16.61mΩ 3.34/METAL FILM#5/6 3/5%', 'Resistors')
#
# ('7/3,GENERAL PURPOSE/SNAP_1.25 CABLE', 'Connectors')
#
# ('SOP Remote Control ICs-4/9_1.8/10 1', 'Consumer Circuits')
#
# ('3.4µF#-55.0°C_X7R,25.0kV YES,125.0°C Array/Network Capacitors', 'Capacitors')
#
# ('19550.0Ω-BULK:445.0#3/6%;1.105nW;60.0', 'Resistors')
#
# ('1.5#RG/2/7#-47.5;150.0;3580.0;METAL OXIDE FILM;xCT:04EF110H375TRF', 'Resistors')
#
# ('1610.0nm;2/10,7.5:5.5mm:Fiber Optics/2/5nm#GBE, ITU-T-G.692, OC-192, SDH', 'Fiber Optics')
#
# ('3.0dB#7/3°C-8x7-4,95.0°C#50.0ohm e4-1#1.575', 'RF and Microwave')
#
# ('20.015mm:AEC-Q200-贴片电容#WRAPAROUND;1206#3.401e-05µF/10/10% 62.5kV', 'Capacitors')
#
# ('Fixed Resistors:2:贴片电阻#75ppm/°C-0.012kΩ,METAL STRIP-5/9°C:0805,WSLP060;3', 'Resistors')
#
# ('0.22µF#Paper Capacitors,400.0uV-CZR23xEF-224M PAPER/MIL-C-11693/7', 'Capacitors')
#
# ('1.75#7/8/Not Qualified_9/7/162.5-9/2;7/3', 'RF and Microwave')
#
# ('6/7%_TANTALUM NITRIDE/NICKEL CHROME,AR03,AR05,7960.0Ohm_9/9mm', 'Resistors')
#
# ('0805-125.0°C/8/6mm_CERAMIC:0.009µF_Matte Tin (Sn)_62.5kV', 'Capacitors')
#
# ('Trigger Devices-1#SINGLE:1.1;Trigger 150.0nA/NOT SPECIFIED', 'Trigger Devices')
#
# ('YES:9/7:-10,10 Chip 1/10,0.26,28.1,Resistors/1206', 'Resistors')
#
# ('YES/2.5,tele;4.15kV-SINGLE-ENDED/DIFF-SYNCHRONOUS-2/1/VOLTAGE', 'Telecommunication Circuits')
#
# ('10/1 97.5°C;30.95:THROUGH-HOLE:5.0V:1/3°C-28.232 9/6', 'Microcontrollers and Processors')
#
# ('550.0uV x2x0X43xMx0xN;W,8/3µF;5.5%,RECTANGULAR PACKAGE', 'Capacitors')
#
# ...
#
# ('3.465-2.12;100ppm/°C/METAL GLAZE/THICK FILM:TR; TUBE:565.0MΩ', 'Resistors')
#
# ('Matte Tin (Sn)#0.5uW_SWITCH OPTION AVAILABLE:4400.0ohm,res/100', 'Resistors')
#
# ('642000.0O#2/10/2.035_5.04-3/7%:5ppm/°C', 'Resistors')
#
# ('RF and Microwave-YES-1/7-RF#9/5dB-DIRECTIONAL COUPLER', 'RF and Microwave')
#
# ('8.755_1430.0nm_1100.0nm_-40.0°C/0.875A/W:40.0 8/10nm:85.0°C', 'Fiber Optics')
#
# ('6/3_4.15mV#3.6/5V 0.5 SMALL OUTLINE, VERY THIN PROFILE', 'Microcontrollers and Processors')
#
# ('0.002µF_0/+70ppm/Celppm/°C;MIL-PRF-39001_500.0V_2:MICA', 'Capacitors')
#
# ('5.0/41250800.0GΩ_3.5uW/38.1mm:电阻-WIRE;Cylindrical_8739', 'Resistors')
#
# ('TANTALUM (DRY/SOLID)_75.5µF,2/5;TR, 13 INCH,POLARIZED_9/6mA-12.5%', 'Capacitors')
#
# ('MIL-STD-202, AEC-Q200;SPUOPENSTYLE;5044-METAL ALLOY,WIRE_980031.7GΩ,2.8MW', 'Resistors')
#
# ('6939#THROUGH HOLE MOUNT-RATED AC VOLTAGE (V): 160:Cap-0.028µF;POLYPROPYLENE', 'Capacitors')
#
# ('2/8µF xZR23BEx1:05M_PAPER 600.0V:Capacitors', 'Capacitors')
#
# ('5511-e3 3:0.55%/0.082nW 23.71K', 'Resistors')
#
# ('10.9kHz 1.05mV#20.0 8/5mm/NOT SPECIFIED,0.43', 'Transformers')
#
# ('-55.0°C_0603:Fixed Resistors FIXED RESISTOR/0.1%,Tantalum Nitride/Nickel Chrome Resistors TANTALUM NITRIDE/NICKEL CHROME#3985.0Ω', 'Resistors')
#
# ('FIlters/105.0/772.5_N FEMALE 30.0-Gold (Au) - with Nickel (Ni) barrier', 'Filters')
#
# ('NON-POLARIZED#Capacitors-2--250ppm/Cel-115.0°C#5.75µF_2/8%/-55.0°C,1625.0V', 'Capacitors')
#
# ('15.3mm-METAL ALLOY:275.0:4.0%#e3;1.438GW/3/1_0.005ohm#-55.0', 'Resistors')
#
# ('COLLECTOR_0.077;5/9_PNP 1.0A/NOT SPECIFIED,三级管', 'Transistors')
#
# ('RNX:Cylindrical_2.5MW/100ppm/°C-8739,TR_41258700.0GΩ,NO', 'Resistors')
#
# ('425.0mV 340600.0ohm Resistors:2.0%:Cylindrical:0.4nW/9/5', 'Resistors')
#
# ('SURFACE MOUNT:Ruthenium Oxide Resistors;517.4Ohm-0.562W#Resistors#0505', 'Resistors')
#
# ('3.875kV//xA48110E-10-8/2-Solid State Relays:2.0_NO;Led', 'Optoelectronics')
#
# ('MIL-PRF-23269;3.5%,Axial/5.0%_0.6e-05µF GLASS/CYR15 400.0uV', 'Capacitors')
#
# ('CZR24/8/8µF_PAPER,300.0uV,Cap;NO 2', 'Capacitors')
#
# ('2/7-WHITE FEMALE#BRASS/Connect:MBx9D0975##e4/BNC-BNC,NO', 'Connectors')
#
# ('x23;269/013076#Capacitors;9/1%-1.951µF#400.0mV', 'Capacitors')
#
# ('2,34185.0Ohm_e3 贴片电阻/1.0W,1010', 'Resistors')
#
# ('DC:240.0 22.5_THROUGH HOLE-STRAIGHT MOUNT 65000.0-810mW_77.5;-32.5_8.0nA', 'Relays')
#
# ('239.0uV_NO:250.0/UL RECOGNIZED#9/3/10/8', 'Trigger Devices')
#
# ('8645.0MΩ/GULL WING,1.05% BULK/16;0.5GW:VHD144;THIN FILM', 'Resistors')
#
# ('175.0_39.358K#1500_CARBON FILM;CBB 0207 SURFACE MOUNT', 'Resistors')
#
# ('1_0.4mm 42/NO/Connectors,FEMALE#LOCKING 0.04', 'Connectors')
#
# ('On Request 3920-9/9µF KP18_x021x6x5,6.9mm,10.0%#259P_NON-POLARIZED', 'Capacitors')
#
# ('-60.0°C/1/8µF,125.0°C_1.05kV:1812#SURFACE MOUNT', 'Capacitors')
#
# ('X7R:0.75µF TR, 13 INCH-TANTALUM CAPACITOR:1111', 'Capacitors')
#
# ('CERAMIC-37.5uV;5.0:3.3mm#cap,0.008µF', 'Capacitors')
#
# ('Paper Capacitors,PAPER-5/6µF,电容#300.0mV_Capacitors', 'Capacitors')
#
# ('MALE/POLARIZED HOUSING;R317_580/0.632#2.1 1', 'Connectors')
#
# ('4.15e-05µF:10/10°C#2/400.0uV,3.5%#+140+/-25ppm/Celppm/°C#GLASS:-55.0°C#3.58mm', 'Capacitors')
#
# ('25.4mm:50_9/8,0.81mm,Tin/Lead (Sn60Pb40)_METAL ALLOY,1.438uW#23.495mm 3.3 res#166.001O', 'Resistors')
#
# ('MIL-R-39008/6550000.0R TR,70.0°C;0.5GW 7.5%;CARBON COMPOSITION', 'Resistors')
#
# ('4.3e-05:1816/5.5_10/2-e3,MIL-PRF-81;MICA', 'Capacitors')
#
# ('1000VAC GLASS FILLED POLYBUTYLENE TEREPHTHALATE-5-0.588 2,2.25', 'Connectors')
#
# ('8/3:0504,2:5000002.8ohm:METAL GLAZE/THICK FILM', 'Resistors')
#
# ('CONSTANT-CURRENT;10/6°C:GULL WING;10/4,1.0 SERIAL--40.0°C', 'Drivers And Interfaces')
#
# ('RIGHT-4.0 POSITIVE EDGE_SYNCHRONOUS#300kRad(Si)V/Shift Registers/38535Q/M;38534H;883B/1.0', 'Logic')
#
# ('3.75dB_5/6dB FC/APC CONNECTOR#Fiber Optic Filters/6/3°C-70.0°C,1565.0nm_3/3nm', 'Fiber Optics')
#
# ('PAPER CAPACITOR:600.0V#MIL-C-11693/7#3/10µF;PAPER/NO', 'Capacitors')
#
# ('NPQ-VERTICAL-7/10;2.1e-05-Yes,625.0;75.0/BFC280832659', 'Capacitors')
#
# ('7.5% Other Tolerance Values on Request;0.06µF 250.0mV;MIL-C-39022/1', 'Capacitors')
#
# ('2 19.05mm/11.0%_GLASS_1.655%/1.4e-05µF/400.0uV Axial', 'Capacitors')
#
# ('6/1µF,YES_POLARIZED/3.565mm-2010', 'Capacitors')
#
# ('Radial#6920_电容-531.5V;0.05µF;102.5°C--250ppm/Cel:-55.0°C-NON-POLARIZED', 'Capacitors')
#
# ('FIXED RESISTOR TUBULAR PACKAGE#400ppm/°C;336.949Ohm 0.3%', 'Resistors')
#
# ('0805#2.03mm,1.0%/0.33mm 0.013Ohm/Fixed Resistors', 'Resistors')
#
# ('4.3e-0_CERAMIC;G-ME9x3x1#75.0_1816/Tape & Reel Available:Variable Capacitors#-/+30ppm/Cel', 'Capacitors')
#
# ('3.0 13.344/POLYTETRAFLUORO ETHYLENE,NICKEL:BRASS:5000000000.0', 'Connectors')
#
# ('POLARIZED#4/6µF#e3:1808#CERAMIC:IEC60384-19#361.0', 'Capacitors')
#
# ('9/8%_Pure Matte Tin (Sn) - with Nickel (Ni) barrier 0.425W-425.0V/CARBON FILM,468500.0GΩ/2.5', 'Resistors')
#
# ('1.1pW J BEND 2.5;METAL OXIDE FILM', 'Resistors')
#
# ('5/3mm,3.0mm,1.55uW#4.2kΩ:10/5%_4/8-PRECISION, FUSING POWER: 15 TIMES RATED POWER_METAL FILM', 'Resistors')
#
# ('1380.0-85.0°C:0.45;7/1,1270.0 NOT SPECIFIED--40.0°C', 'Fiber Optics')
#
# ('0805/METAL FILM/Fusible Resistors#215.0°C FRM:-55.0°C;60.0ns#1.051mΩ', 'Resistors')
#
# ('625; 1125; 1375; 1750; 2500#TUBULAR PACKAGE Tubular,9/8-0.188mW:5165.0MΩ', 'Resistors')
#
# ('10.0Ohm:5/8%:87.5V#Chip-0805', 'Resistors')
#
# ('MIL-PRF-83401;0.75%;Matte Tin (Sn) - with Nickel (Ni) barrier,0304_SURFACE MOUNT 136.35kΩ-贴片电阻/0.525nW', 'Resistors')
#
# ('POLARIZED-16523.5µF:EKA:BINDING POST-4.65;ALUMINUM (WET)', 'Capacitors')
#
# ('0V:79.005Psi/Sensors/Transducers#GAGE/IP 67-CYLINDRICAL', 'Sensors/Transducers')
#
# ('MAGAZINE,CERAMIC:Yes;2.0e-06;NP0', 'Capacitors')
#
# ('5/1:NO-NO:2.5,3.3V;8/6#NO/M8C/ATA-2; SCSI', 'Microcontrollers and Processors')
#
# ('-55.0°C#4380.0R,500ppm/°C#200.0°C;0603:TUBULAR PACKAGE', 'Resistors')
#
# ('6/7,155.0Mbps_OC-192, SONET 9/125, SMF_1360.0#9/4,4.15V_8/5nm#Fiber Optic Transceivers', 'Fiber Optics')
#
# ('CERAMIC YES,SURFACE MOUNT/-55.0°C#62.5V_125.0°C_Yes;C0G/2.806e-05µF', 'Capacitors')
#
# ('ALUMINUM ALLOY;OPTICAL FIBER:ONE-0.375dB-MALE-NG-xN/2BS9x4WW-M001 9/125um', 'Connectors')
#
# ('贴片电阻-3.5pW/TR#ZBS303(4 TC,J TOL):Fixed Resistors/WIRE WOUND#635.302R', 'Resistors')
#
# ('2/1µF:3.0%-C0G,76.0-50.0mV-3.285mm 1.425mm SMT', 'Capacitors')
#
# ('e4;1000ppm/°C:333.0GΩ_1010/电阻_0.45mW-1.425 FLAME PROOF, PRECISION#SURFACE MOUNT', 'Resistors')
#
# ('16;5.0kV/256_9/6°C,8/4°C#NO,BINARY CODED DECIMAL', 'Converters')
#
# ('2#70.0kV_0.125GW_FIXED RESISTOR-METAL GLAZE/THICK FILM#1482.5Ohm', 'Resistors')
#
# ('50.0K,RF SMB/SSMB Connectors_10/2;275.0/160.0', 'Connectors')
#
# ('CERAMIC:SMT;6/1%#0.001µF#电容 VJ HIGH REL X7R', 'Capacitors')
#
# ('200.0;10/8mA:140.0°C,54.5mV/O-PBCY-T3:-55.0°C;7.25V', 'Trigger Devices')
#
# ('MIL-R-11 10/9%,0.375W#56500.0MΩ:TIN#2;1333:e3', 'Resistors')
#
# ('e0,140.0R;1.27mm;0.163W_M0603-0805(F TOL):Resistors:METAL GLAZE/THICK FILM#2.0%', 'Resistors')
#
# ('5.25W#Cylindrical-350ppm/°C,Rx732A-TTD680J#Resistors-340.488Ω/Res', 'Resistors')
#
# ('-55.0°C 2/7-电阻,190.0°C#2121300.0Ω:200ppm/°C:2/1mm,8739:7/1°C', 'Resistors')
#
# ('1411-195.0µF_551.0_-82/+22%:13.75', 'Capacitors')
#
# ('4.95#8000.0-10/10-POLARIZED#RECTANGULAR PACKAGE NIOBIUM/235016.5µF', 'Capacitors')
#
# ('Fixed Capacitors/0.571mA;2187.5:20.0uV_5.003µF/20.0,e3:12.5%', 'Capacitors')
#
# ('Mica Capacitors#电容 TIN_MICA 3.5%/5/1µF,TR,500.0V', 'Capacitors')
#
# ('2-0.13%_9013.0GΩ#2010 VxM12:06312R00TCR2TBT', 'Resistors')
#
# ('3/7e-06µF;CERAMIC,1210#3/6%#1.425mm/CERAMIC CAPACITOR:Yes', 'Capacitors')
#
# ('CARBON FILM:RATED AC VOLTAGE (V): 350,11.35kΩ:2309 TUBULAR PACKAGE', 'Resistors')
#
# ('5/10°C#NO#36.0 2.65,24.0:3.4-2/1 3/6°C', 'Microcontrollers and Processors')
#
# ('25.11µs-2.0/Peripheral Drivers/STANDARD 7.7mm', 'Drivers And Interfaces')
#
# ('AEC-Q200/1.0% 0.014GΩ_METAL STRIP#7/4mm 0.33mm', 'Resistors')
#
# ('5V;CMOS#5.0uV_2048.0Mbps-0.013mA', 'Telecommunication Circuits')
#
# ('e0/3.95,SILICON Diodes;8.0kA/UNSPECIFIED', 'Diodes')
#
# ('15.45µF_3333:TIN LEAD,44.0kV_10 % Tolerance Available On Request', 'Capacitors')
#
# ('TR, PAPER, 7 INCH,RMKHT:2512/贴片电阻_2,1/5%;25ppm/°C;20.788K:SMT', 'Resistors')
#
# ('10.0%/10/9µF;85.0°C,8/3°C/2.4mm,1.8kV,NIOBIUM OXIDE#Bulk/3.5mm', 'Capacitors')
#
# ('6/1;3_FIXED/TAPE AND REEL;3.0uV/R-XDSO-G8', 'Power Circuits')
#
# ('29.0;e0,OPEN-EMITTER-16;FLAT 2.0;1/3mm_17.0ns', 'Logic')
#
# ('32.0;1/10_3-2,500.0,0.165/PREASSEM CONN', 'Connectors')
#
# ('815.0uV No#7126 Radial,电容;0.176µF,Other Tolerances Values On Request', 'Capacitors')
#
# ('6.035R_NON INDUCTIVE#6/8%-11.695/5.0mW#4/6', 'Resistors')
#
# ('cap#CERAMIC/0.004µF-Tin/Lead (Sn/Pb)-C0G/RECTANGULAR PACKAGE#1206 10.0%', 'Capacitors')
#
# ('4/5-X7R#0.15/0.009mA 12.65µF', 'Capacitors')
#
# ('Axial:Fixed Resistors LCA0414-0.425mW;1500-NON-INDUCTIVE#3/9%_338000.0GΩ', 'Resistors')
#
# ('6.25kV/RECTANGULAR PACKAGE_Special Capacitors#2917/57.5µF', 'Capacitors')
#
# ('341.5K#8/3%-192.5:8.0_3582.0 0.355GW:60.0', 'Resistors')
#
# ('3.0%:3/3e-05µF_300.0uV 7220/SURFACE MOUNT/125.0°C,1/8_Capacitors:-55.0°C', 'Capacitors')
#
# ('cap-900.0mV-7.5%#NON-POLARIZED#0.017µF;2 NO e3', 'Capacitors')
#
# ('0.36-1.44V/25.0#RECTANGULAR/7/3;1.0#30.0 1000.0', 'Sensors/Transducers')
#
# ('1210_500.0kV,CMR04x122xPD;R 35.3/3.15e-05µF;4/2%#2', 'Capacitors')
#
# ('675.0mV,3022,10/3mm WIRE_10/4µF THROUGH HOLE MOUNT', 'Capacitors')
#
# ('6/9;5000000000.0/UL:CABLE#22.24_1.46dB', 'Connectors')
#
# ('1/3/0.9/1.27#2.4#Optocoupler - IC Outputs/6/3;Led/3/1:Tin/Lead (Sn/Pb)', 'Optoelectronics')
#
# ('69.0dB-2.5:15.0kV/TLx251Bx#P_YES_NO LEAD/Amp', 'Amplifier Circuits')
#
# ('2#5732-4.14#CERMET 110100.0GΩ', 'Resistors')
#
# ('600.0uV_5/6µF_Capacitors-PAPER-CHASSIS MOUNT,CZR23', 'Capacitors')
#
# ('3.508µF x6x3Y122_KXHWDx4MLS-POLARIZED-TR;e0_6500.0', 'Capacitors')
#
# ('0.007uA#5/3:950_Other Optoelectronics;Tin/Lead (Sn/Pb)', 'Optoelectronics')
#
# ('5.25%_FIXED RESISTOR,METAL GLAZE/THICK FILM e2 1005,E/H-MILITARYM/D55342/47.5°C-2110255.0Ohm', 'Resistors')
#
# ('3.5mm:2.15kV 345.0µF:10.0%;xBJC157M1R8CWSC080#0,15.0%', 'Capacitors')
#
# ('Tin/Lead (Sn/Pb)-0.5,2.2kV:6/10-13.27mm#4.1', 'Transformers')
#
# ('Rectangular_2_0.16uW#METAL FOIL;-2.5,2.5ppm/°C#e0#54662.0ohm', 'Resistors')
#
# ('0.1 15.0%,4/3%/IEC60384-4:2/6µF#ALUMINUM (WET)/MAL/2123xx221E3/POLARIZED', 'Capacitors')
#
# ('625.0kV-Capacitors,x1710--327K3ILW0_0.039µF 2,RECTANGULAR PACKAGE NON-POLARIZED', 'Capacitors')
#
# ('AIR:4.5:MIL-C-81;Yes_4/3e-05#1210;30.0', 'Capacitors')
#
# ('MIL-PRF-55182_7/7#1/9%--60.0°C,4527_70.0°C:0.55nW/5.0;2060001.0ohm:38.1', 'Resistors')
#
# ('221-B:2.75A_CHASSIS MOUNT L230.0XB140.0XH160.0 (mm);NOT SPECIFIED', 'Transformers')
#
# ('CERAMIC:7/9%/1.659µF Capacitors/125.0°C#7/8mm:-55.0°C;76.0#BP#0603', 'Capacitors')
#
# ('Trans,55.0µH-0.25 ABT-4-4C#4.598mm-50 OHMS#1:2', 'Transformers')
#
# ('INDUSTRIAL;2.0/DIP_32.768 KHZ#MOS', 'Consumer Circuits')
#
# ('METAL STRIP#70.0°C,Metal Strip/Wire Resistors:-65.0°C Fixed Resistors_0.014kΩ#0.5kW;75ppm/°C', 'Resistors')
#
# ('2164030.0O:Tin/Lead (Sn/Pb):Axial:TR_METAL OXIDE FILM-2.0GW', 'Resistors')
#
# ('0.355GW;RADIAL 35100.0GΩ 130.0,10.5%;Non-linear Resistors', 'Resistors')
#
# ('NxSE227M00_6LxDx0024_SPECIAL CAPACITOR#10/4%#66.5µF_375.0;2924', 'Capacitors')
#
# ('5V 3/1e-05A-3/8°C_3/10,Memory,10/6°C_41.5', 'Memory')
#
# ('25ppm/°C_14615.0GΩ,ARRAY/NETWORK RESISTOR-2.0%/5/7mm_METAL GLAZE/THICK FILM_1.689mm;2.095mm', 'Resistors')
#
# ('5044 8/2mm;Bulk-70.0°C;2/10%/Resistors METAL ALLOY 4.125/165.0kΩ', 'Resistors')
#
# ('3.5mm x 1.8mm x 0.9mm 7.5%/TEMPERATURE SENSING-res/0.12uW#CHASSIS MOUNT,43550.0Ω', 'Resistors')
#
# ('ANTI-SULFUR/Resistors#Rectangular#200 34.054kΩ:0502', 'Resistors')
#
# ('DIP40,.6 COMMON;128KX8-266240.0G 5#120.0ns-1.0,4/2', 'Memory')
#
# ('0505 WRAPAROUND:RECTANGULAR PACKAGE 309526.8GΩ#0.1nW_SMT_3.0%', 'Resistors')
#
# ('7960.0Ω:1.025mm;0805/TR-TANTALUM NITRIDE/NICKEL CHROME-AR03', 'Resistors')
#
# ('1.55uA:1.95ohm/10/3 L9.02XB8.76XH7.62 (mm)/L0.355XB0.345XH0.3 (inch)#e2_165.0V:62.5-600OHMΩ', 'Filters')
#
# ('3.437:THIN FILM,5/8%-22448.8MΩ/1.715#150.0°C:90.0kV;-55.0°C', 'Resistors')
#
# ('res#280.0mV 1.565;MIL-PRF-32192/2-2/1/0603-4/1--10,10', 'Resistors')
#
# ('21805.0Ohm-RL#1206-5/6,200.0mV_0.575nW 33.05mm;METAL GLAZE/THICK FILM', 'Resistors')
#
# ('164.0ns#MIL-PRF-38535 Class Q;Not Qualified_逻辑电路;5.7mm-4.0#3-STATE', 'Logic')
#
# ('RIGHT ANGLE/BLACK/S6P2 26.5A-10/1Cycles;FEMALE', 'Connectors')
#
# ('All-Welded#4/2°C--60.0°C 2.0MW;WIRE WOUND;0.525% 2.775ohm,res_RWR71NR2;05FMxSL', 'Resistors')
#
# ('Not Qualified;8/10%-50 7.5MHz;3.462_3.945 Gold (Au) - with Nickel (Ni) barrier#NO/4.15mV', 'Oscillators')
#
# ('13.175,1.5kW:THROUGH HOLE MOUNT:1.0%/100ppm/°C:262250.0ohm 7.37mm-Axial', 'Resistors')
#
# ('3720.5:10110.0R;7/8%:电阻;e0 SMT', 'Resistors')
#
# ('0.77,Diodes;1/10µs_1.0nA_EFFICIENCY_260', 'Diodes')
#
# ('2.515GΩ/MIL-PRF-39007 Wire Wound Resistors,6927;50ppm/°C', 'Resistors')
#
# ('1/5mm:73.5µF/FILM CAPACITOR,20.0%:NIOBIUM OXIDE/1411;#xBJC686K2R5CRSC0823#2.5V', 'Capacitors')
#
# ('DIP;OTHER_PAL; NTSC;28.14mm;2/3', 'Consumer Circuits')
#
# ('SURFACE MOUNT#Capacitors:9/8µF,6/2#NIOBIUM-20.0%,Contact Manufacturer For Other Values', 'Capacitors')
#
# ('0.04-通讯电路:13.5#BIPOLAR,5.0uV_PLASTIC/EPOXY#FLATPACK, THIN PROFILE, FINE PITCH', 'Telecommunication Circuits')
#
# ('ALSO AVAILABLE IN QIP48E PACKAGE_CORTEX-M3;260_40/4.0:8.0-4.0mV Processors', 'Microcontrollers and Processors')
#
# ('13.15V;9/3µF#0.12_1.502mA#POLARIZED', 'Capacitors')
#
# ('NIOBIUM OXIDE/Capacitors:15.0%:109.0µF_Other Capacitors', 'Capacitors')
#
# ('7/6µF;C0G_4/2°C 4/1°C#105.0_2225', 'Capacitors')
#
# ('2.15V#NIOBIUM OXIDE#9/10mm_534.0µF:Other Capacitors', 'Capacitors')
#
# ('5.5%:11.5kV,Resistors-TUBULAR PACKAGE:4881245.0R,150ppm/°C--55.0°C-225.0°C,8739', 'Resistors')
#
# ('FEMALE;MIL-C-22992-13-M39029/16-167', 'Connector Support')
#
# ('7122 7.5%-CFR15 55.0uV,YES,0.35µF_Cap#NON-POLARIZED', 'Capacitors')
#
# ('25.4-5/6,METAL FOIL-3/4%,e0_47400.0O', 'Resistors')
#
# ('e3-0.225µF#4/8mm-NON-POLARIZED-400.0uV#MKP', 'Capacitors')
#
# ('45ppm/Cel/26.35,0.098µF-7028_NON-POLARIZED-WIRE', 'Capacitors')
#
# ('1.25µF/700.0#T83:Tantalum Capacitors:TANTALUM (DRY/SOLID)', 'Capacitors')
#
# ('CERMET:-150,150_200.0mΩ,Resistors/2/2', 'Resistors')
#
# ('MICA:e0;400.0kV;5/8%:4.5e-06µF--55.0°C 2/8°C-CD5CC010D0,3 TAPE', 'Capacitors')
#
# ('YES#0705#-55.0°C/125.0°C:0.1%/FIXED RESISTOR-515000.0R', 'Resistors')
#
# ('500.0kV:3/1%#MICA 8/5e-05µF#0805:Mica Capacitors-6/9/电容', 'Capacitors')
#
# ('300.0uV:13.85 1812;7.5e-05µF 19.05:-55.0°C-3/6°C', 'Capacitors')
#
# ('5.5%-Chip,12.055mm,24.2mm_0.515nW 38.099mm 3140.0ohm/500ppm/°C_FIXED RESISTOR - FUSIBLE', 'Resistors')
#
# ('137.5-THROUGH HOLE MOUNT:3140#4.25e-06--52.5:125.0-50.0;4.0', 'Capacitors')
#
# ('501.1µF 0.001mA/2 SMT POLARIZED,TANTALUM', 'Capacitors')
#
# ('LOW PROFILE#SPST#DRY REED SWITCH,Switches 200.0V:1.75pA', 'Switches')
#
# ('YES#Not Qualified_4/8MHz-110.0 3:5/5', 'Transistors')
#
# ('2/8°C#1/10°C:1.75e-06µF:1812/CERAMIC_MIL-PRF-55681-10/10%', 'Capacitors')
#
# ('0505#SURFACE MOUNT-15.585 5.08:Fixed Resistors#THIN FILM/410.5Ohm', 'Resistors')
#
# ('77.5°C/65.0-CERAMIC_9.0/796.25/Oscillators 25 pF;9/5:-10.0°C-2/5', 'Oscillators')
#
# ('UL RECOGNIZED;NOT SPECIFIED_8/8;RECTANGULAR/1.5#265.0', 'Trigger Devices')
#
# ('162.25K-METAL FOIL#0.06%-NO#FIXED RESISTOR', 'Resistors')
#
# ('0.625%:FIXED RESISTOR,15.85K THROUGH HOLE MOUNT#NO:METAL ALLOY', 'Resistors')
#
# ('5/1_1/2µF:224.5mΩ,ALUMINUM (WET):Cardboard#Cap', 'Capacitors')
#
# ('20.5V#RECTANGULAR PACKAGE-0.004µF_0805/Yes-3/10°C MA-125.0°C_CERAMIC', 'Capacitors')
#
# ('NO NO;3.5;MALE 2/1-675.0;19.0#380-014', 'Connector Support')
#
# ('C0G;5000000.0#T_BCLx7xM020CRSC072x:CERAMIC_7/3µF/20.5V#0.001mA', 'Capacitors')
#
# ('100ppm/°C,5/8mm:0.562mW:0.673mm#YES,16525.5R', 'Resistors')
#
# ('PAPER CAPACITOR,1/6µF,1/8°C 400.0mV-THROUGH HOLE MOUNT_-55.0°C,PAPER', 'Capacitors')
#
# ('3.4mV;2.9,2.622 1.5/Power Circuits_1.61kV/6/3mm_O-MBFM-P2', 'Power Circuits')
#
# ('MIL-PRF-23269,GLASS,e0,8/5°C;0.001µF-7/2%_500.0kV_3/9°C', 'Capacitors')
#
# ('9/2%_2-WIRE:1.65e-05µF_400.0kV 3/6/STANDARD: MIL-PRF-39001_MICA', 'Capacitors')
#
# ('-47.5°C#Resistors,SURFACE MOUNT/253700.0MΩ 50ppm/°C/1.2nW,137.5°C_RECTANGULAR PACKAGE', 'Resistors')
#
# ('16 3.341mΩ;SURFACE MOUNT,0.9uW;10/5_TUBE:1534_THIN FILM', 'Resistors')

# %%
# #保存列表，每行一个元素
# with open('example.txt','w',encoding='utf-8') as f:
#     f.write('\n'.join(a))

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# %%
def train_input_process(config_classinfo,model_checkpoint,train_size,class_dict,tokenizer):
    """
    """
#    files= os.listdir('./class_inputData')

    with open('running_output.txt','w') as f:
        f.write(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())+'\n')
    
    #准备训练数据
#    print('train dataset\n')
#     if 'train_encodings.pt' in files and 'train_labels.csv' in files:
#         print('read train dataset\n')
#         train_encodings = torch.load('./class_inputData/train_encodings.pt')
#         train_labels = pd.read_csv('./class_inputData/train_labels.csv',index_col=0)
#         train_labels = train_labels['0'].to_list()
#     else:
#    print('generate train dataset\n')
    train_dataset,train_labels = get_input_from_sampling(train_size,train_flag=True)
    train_encodings = tokenizer(train_dataset,padding=True,truncation=False)

#     pd.DataFrame(train_labels).to_csv('./class_inputData/train_labels.csv')
#     torch.save(train_encodings, './class_inputData/train_encodings.pt')
#     print('train dataset saved')
        
    # encode the labels
    train_labels_encoded = list(map(lambda x:ClassEncoder(x),train_labels))

    print('training dataset is ok\n')
    return train_encodings,train_labels_encoded

def test_input_process(config_classinfo,model_checkpoint,test_size,class_dict,tokenizer):
    """
    """
#    print('test dataset')
#    files= os.listdir('./class_inputData')
    
#     if 'test_encodings.pt' in files and 'test_labels.csv' in files:
#         print('read test dataset\n')
#         test_encodings = torch.load('./class_inputData/test_encodings.pt')
#         test_labels = pd.read_csv('./class_inputData/test_labels.csv',index_col=0)
#         test_labels = test_labels['0'].to_list()
#     else:
    print('generate test dataset\n')
    test_dataset,test_labels = get_input_from_sampling(test_size,train_flag=False)
    test_encodings = tokenizer(test_dataset,padding=True,truncation=False)

#         torch.save(test_encodings, './class_inputData/test_encodings.pt')
#         pd.DataFrame(test_labels).to_csv('./class_inputData/test_labels.csv')
#         print('test dataset saved\n')

    # encode the labels
    test_labels_encoded = list(map(lambda x:ClassEncoder(x),test_labels))
    print('testing dataset is ok\n')
    return test_encodings,test_labels_encoded

# %%
class processDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
def ClassEncoder(Class):
    if Class == 'Resistors':
        return 1
    elif Class == 'Capacitors':
        return 2
    else:
        return 0
    
def ClassDecoder(Class):
    if Class == 1:
        return 'Resistors'
    elif Class == 2:
        return 'Capacitors'
    else:
        return 'Others'

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='micro')
    acc = accuracy_score(labels, preds)
    
    global class_dict
    print('compute_metrics:',len(labels))

    res = pd.DataFrame({"preds":preds,"labels":labels})
    res[:1000].to_csv('test_set_result.csv')
    
    class_preds = [ClassDecoder(item) for item in preds]
    class_labels = [ClassDecoder(item) for item in labels]
    class_report = classification_report(class_labels, class_preds,output_dict=True)
    class_report2 = classification_report(class_labels, class_preds)
    class_result = {'accuracy': acc,
                'f1': f1,
                'precision': precision,
                'recall': recall}
    
    with open('class_classification_report.json','a',errors='ignore') as f: 
        json.dump(class_report,f,ensure_ascii=False, indent = 4) 
#     with open('class_classification_report_string_format.txt','w') as f: 
#         f.write(class_report2)
#     with open('class_running_output.txt','w') as f:
#         f.write('class_result:'+str(class_result)+'\n')

    return class_result

# %%
if __name__=="__main__":

    set_seed(1024)
    #model_checkpoint = "albert-base-v2"
    model_checkpoint = "prajjwal1/bert-tiny"
    # model_checkpoint = r'C:\Users\coldkiller\Desktop\supplyframe\checkpoint-3500'
    
    gpu_available = torch.cuda.is_available()
    tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
    
    print('torch.cuda.is_available()',gpu_available)
    
    model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=3)

    training_args = TrainingArguments(
        output_dir='./results',
        dataloader_num_workers=7,
        do_train = True,
        learning_rate=1e-5,
        weight_decay=0.01,
        adam_beta1=0.9,
        adam_beta2=0.999,
        adam_epsilon=1e-8,
        num_train_epochs=100,
        logging_steps=100,
        save_steps=500000,
        no_cuda= not gpu_available,
        seed=1024,
        per_device_train_batch_size=256,
        per_device_eval_batch_size=256,
        warmup_steps=5,
        logging_dir='./logs',
        load_best_model_at_end=True,
        save_total_limit=5,
        disable_tqdm=True
    )

    for i in range(25):
        print(f'\n\nbegin generate train_dataset{i}\n\n')
        train_data,train_labels_encoded = train_input_process(config_classinfo,model_checkpoint,200,class_dict,tokenizer)
        print('sys.getsizeof(train_data)',sys.getsizeof(train_data))
        train_dataset = processDataset(train_data, train_labels_encoded)
        print('sys.getsizeof(train_dataset)',sys.getsizeof(train_dataset))
        
#         if i>0:
#             trainer.args.learning_rate = tmp_learning_rate
        
        trainer = Trainer(
            model=model,
            args=training_args,
            tokenizer=tokenizer,
            compute_metrics=compute_metrics,
            train_dataset=train_dataset
        )

        # Train the model
        print('Training begins\n')
        start = time.time()
        trainer.train()
        end = time.time()
        print(f"training time: {end - start}")

        #为下一批训练数据做初始化
        trainer.args.warmup_steps=0
        #tmp_learning_rate = trainer.args.learning_rate
        gc.collect()

    #保存模型
    trainer.save_model()
    
    # generate test data
    
    test_data,test_labels_encoded = test_input_process(config_classinfo,model_checkpoint,100,class_dict,tokenizer)
    print('sys.getsizeof(test_data)',sys.getsizeof(test_data))
    test_dataset = processDataset(test_data, test_labels_encoded)
    
    with open(r'testDesc(cap&res).json', 'r', errors='ignore', encoding='utf-8') as f:
        js = f.read()
        real_input = json.loads(js, strict=False, encoding="GB2312")['descriptions']
        labels=[1]*404
    
    real_encodings = tokenizer(real_input,padding=True,truncation=False)
    real_dataset = processDataset(real_encodings,labels)
    
    
    train_result = trainer.predict(train_dataset).metrics
    print(train_result)
    test_result = trainer.predict(test_dataset).metrics
    print(test_result)
    
    real_result = trainer.predict(real_dataset).predictions.argmax(-1)
    class_result = {}
    for i in range(len(real_input)):
        class_result[real_input[i]]=ClassDecoder(real_result[i])
    
    with open('running_output.txt','a') as f:
        f.write(f"training time: {end - start}"+'\n')
        f.write('train_dataset'+str(train_result)+'\n')        
        f.write('test_dataset'+str(test_result)+'\n')
        
    with open('real_description_output1.json','w',errors='ignore') as f: 
        json.dump(class_result,f,ensure_ascii=False, indent = 4)
# Out:
# torch.cuda.is_available() False
# test dataset
# generate test dataset
#
# 进入数据生成循环
# train_flag False
# problematic set()
# query数量： 37
# label数量： 37
# begin test tokenizer
# finish test tokenizer
# 37
# input_process_finished
#
# sys.getsizeof(test_data) 56
# Some weights of the model checkpoint at prajjwal1/bert-tiny were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at prajjwal1/bert-tiny and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# script running
#
# train dataset
#
# generate train dataset
#
# 进入数据生成循环
# train_flag True
# problematic set()
# query数量： 37
# label数量： 37
# begin train tokenizer
# finish train tokenizer
# 37
# sys.getsizeof(train_data) 56
# Training begins
#
# {'loss': 0.9313957691192627, 'learning_rate': 3.3333333333333333e-06, 'epoch': 0.1}
# {'loss': 1.009919285774231, 'learning_rate': 6.666666666666667e-06, 'epoch': 0.2}
# {'loss': 0.942491888999939, 'learning_rate': 1e-05, 'epoch': 0.3}
# {'loss': 0.9817836284637451, 'learning_rate': 8.571428571428571e-06, 'epoch': 0.4}
# {'loss': 0.9721612930297852, 'learning_rate': 7.1428571428571436e-06, 'epoch': 0.5}
# {'loss': 1.0546274185180664, 'learning_rate': 5.7142857142857145e-06, 'epoch': 0.6}
# {'loss': 1.0171985626220703, 'learning_rate': 4.2857142857142855e-06, 'epoch': 0.7}
# {'loss': 1.0142345428466797, 'learning_rate': 2.8571428571428573e-06, 'epoch': 0.8}
# {'loss': 0.9331746101379395, 'learning_rate': 1.4285714285714286e-06, 'epoch': 0.9}
# {'loss': 1.0118846893310547, 'learning_rate': 0.0, 'epoch': 1.0}
# {'epoch': 1.0}
# training time: 1.2327027320861816

# %%
#改比例，训练数据数量，epoch,dataloader_num_workers

# %%
#trainer.model
